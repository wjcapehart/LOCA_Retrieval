# %% [markdown]
# # Renaming LOCA Repositories

# %% [markdown]
# ## Libraries

# %%
import os    as os

import numpy as np

# %% [markdown]
# ## Control Variables and Arrays

# %%
working_directory = "./"

ftp_prefix = "http://loca.ucsd.edu/public/LOCA_relative_humid_v2/"

thredds_root = "/projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/"

rcps      = ["historical","rcp45","rcp85"]

variables = ["tasmax", "tasmin", "pr", "rhmin", "rhmax"]


ensembles =  ["ACCESS1-0" ,     \
              "ACCESS1-3",      \
              "CCSM4",          \
              "CESM1-BGC",      \
              "CESM1-CAM5",     \
              "CMCC-CMS",       \
              "CMCC-CM",        \
              "CNRM-CM5",       \
              "CSIRO-Mk3-6-0",  \
              "CanESM2",        \
              "FGOALS-g2",      \
              "GFDL-CM3",       \
              "GFDL-ESM2G",     \
              "GFDL-ESM2M",     \
              "HadGEM2-AO",     \
              "HadGEM2-CC",     \
              "HadGEM2-ES",     \
              "IPSL-CM5A-LR",   \
              "IPSL-CM5A-MR",   \
              "MIROC-ESM-CHEM", \
              "MIROC-ESM",      \
              "MIROC5",         \
              "MPI-ESM-LR",     \
              "MPI-ESM-MR",     \
              "MRI-CGCM3",      \
              "NorESM1-M",      \
              "bcc-csm1-1-m"    ]

# %% [markdown]
# ## Processing Loop

# %%
   ### CRB
   #LONCLIP=  [131:1:209] [-106.09375:1:-101.21875]
   #LATCLIP=  [139:1:180] [  42.65625:1:  45.21875]



print(' ')
print(' ')
print('===============================')

for rcp in rcps:
    print('===============================')

    directory = thredds_root + rcp 
    print("cd " + directory)
    os.chdir(directory)

    for ensemble in ensembles:

        print('-------------------------------')


        input_file_nc_name_new = "./NGP_LOCA"    + \
                                  "___"          + \
                                  ensemble  + \
                                  "___"          + \
                                  rcp           + \
                                  ".nc"

        output_file_nc_name_new = "./CHEYENNE_LOCA"    + \
                                  "___"          + \
                                  ensemble  + \
                                  "___"          + \
                                  rcp           + \
                                  ".nc"


        print(output_file_nc_name_new)


        print('- - - - - - - - - - - - - - - -')
        print(    '')
        print(    'ncea -h -4 -d lat,139,180 -d lon,131,209 ' + input_file_nc_name_new + " " + output_file_nc_name_new)
        os.system('ncea -h -4 -d lat,139,180 -d lon,131,209 ' + input_file_nc_name_new + " " + output_file_nc_name_new)
        







print(' ')
print(' ')
# Out:
#
#
# ===============================
# ===============================
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical
# -------------------------------
# ./CHEYENNE_LOCA___ACCESS1-0___historical.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___ACCESS1-0___historical.nc ./CHEYENNE_LOCA___ACCESS1-0___historical.nc
# -------------------------------
# ./CHEYENNE_LOCA___ACCESS1-3___historical.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___ACCESS1-3___historical.nc ./CHEYENNE_LOCA___ACCESS1-3___historical.nc
# -------------------------------
# ./CHEYENNE_LOCA___CCSM4___historical.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___CCSM4___historical.nc ./CHEYENNE_LOCA___CCSM4___historical.nc
# -------------------------------
# ./CHEYENNE_LOCA___CESM1-BGC___historical.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___CESM1-BGC___historical.nc ./CHEYENNE_LOCA___CESM1-BGC___historical.nc
# -------------------------------
# ./CHEYENNE_LOCA___CESM1-CAM5___historical.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___CESM1-CAM5___historical.nc ./CHEYENNE_LOCA___CESM1-CAM5___historical.nc
# -------------------------------
# ./CHEYENNE_LOCA___CMCC-CMS___historical.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___CMCC-CMS___historical.nc ./CHEYENNE_LOCA___CMCC-CMS___historical.nc
# -------------------------------
# ./CHEYENNE_LOCA___CMCC-CM___historical.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___CMCC-CM___historical.nc ./CHEYENNE_LOCA___CMCC-CM___historical.nc
# -------------------------------
# ./CHEYENNE_LOCA___CNRM-CM5___historical.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___CNRM-CM5___historical.nc ./CHEYENNE_LOCA___CNRM-CM5___historical.nc
# -------------------------------
# ./CHEYENNE_LOCA___CSIRO-Mk3-6-0___historical.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___CSIRO-Mk3-6-0___historical.nc ./CHEYENNE_LOCA___CSIRO-Mk3-6-0___historical.nc
# -------------------------------
# ./CHEYENNE_LOCA___CanESM2___historical.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___CanESM2___historical.nc ./CHEYENNE_LOCA___CanESM2___historical.nc
# -------------------------------
# ./CHEYENNE_LOCA___FGOALS-g2___historical.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___FGOALS-g2___historical.nc ./CHEYENNE_LOCA___FGOALS-g2___historical.nc
# -------------------------------
# ./CHEYENNE_LOCA___GFDL-CM3___historical.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___GFDL-CM3___historical.nc ./CHEYENNE_LOCA___GFDL-CM3___historical.nc
# -------------------------------
# ./CHEYENNE_LOCA___GFDL-ESM2G___historical.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___GFDL-ESM2G___historical.nc ./CHEYENNE_LOCA___GFDL-ESM2G___historical.nc
# -------------------------------
# ./CHEYENNE_LOCA___GFDL-ESM2M___historical.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___GFDL-ESM2M___historical.nc ./CHEYENNE_LOCA___GFDL-ESM2M___historical.nc
# -------------------------------
# ./CHEYENNE_LOCA___HadGEM2-AO___historical.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___HadGEM2-AO___historical.nc ./CHEYENNE_LOCA___HadGEM2-AO___historical.nc
# -------------------------------
# ./CHEYENNE_LOCA___HadGEM2-CC___historical.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___HadGEM2-CC___historical.nc ./CHEYENNE_LOCA___HadGEM2-CC___historical.nc
# -------------------------------
# ./CHEYENNE_LOCA___HadGEM2-ES___historical.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___HadGEM2-ES___historical.nc ./CHEYENNE_LOCA___HadGEM2-ES___historical.nc
# -------------------------------
# ./CHEYENNE_LOCA___IPSL-CM5A-LR___historical.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___IPSL-CM5A-LR___historical.nc ./CHEYENNE_LOCA___IPSL-CM5A-LR___historical.nc
# -------------------------------
# ./CHEYENNE_LOCA___IPSL-CM5A-MR___historical.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___IPSL-CM5A-MR___historical.nc ./CHEYENNE_LOCA___IPSL-CM5A-MR___historical.nc
# -------------------------------
# ./CHEYENNE_LOCA___MIROC-ESM-CHEM___historical.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___MIROC-ESM-CHEM___historical.nc ./CHEYENNE_LOCA___MIROC-ESM-CHEM___historical.nc
# -------------------------------
# ./CHEYENNE_LOCA___MIROC-ESM___historical.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___MIROC-ESM___historical.nc ./CHEYENNE_LOCA___MIROC-ESM___historical.nc
# -------------------------------
# ./CHEYENNE_LOCA___MIROC5___historical.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___MIROC5___historical.nc ./CHEYENNE_LOCA___MIROC5___historical.nc
# -------------------------------
# ./CHEYENNE_LOCA___MPI-ESM-LR___historical.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___MPI-ESM-LR___historical.nc ./CHEYENNE_LOCA___MPI-ESM-LR___historical.nc
# -------------------------------
# ./CHEYENNE_LOCA___MPI-ESM-MR___historical.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___MPI-ESM-MR___historical.nc ./CHEYENNE_LOCA___MPI-ESM-MR___historical.nc
# -------------------------------
# ./CHEYENNE_LOCA___MRI-CGCM3___historical.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___MRI-CGCM3___historical.nc ./CHEYENNE_LOCA___MRI-CGCM3___historical.nc
# -------------------------------
# ./CHEYENNE_LOCA___NorESM1-M___historical.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___NorESM1-M___historical.nc ./CHEYENNE_LOCA___NorESM1-M___historical.nc
# -------------------------------
# ./CHEYENNE_LOCA___bcc-csm1-1-m___historical.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___bcc-csm1-1-m___historical.nc ./CHEYENNE_LOCA___bcc-csm1-1-m___historical.nc
# ===============================
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45
# -------------------------------
# ./CHEYENNE_LOCA___ACCESS1-0___rcp45.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___ACCESS1-0___rcp45.nc ./CHEYENNE_LOCA___ACCESS1-0___rcp45.nc
# -------------------------------
# ./CHEYENNE_LOCA___ACCESS1-3___rcp45.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___ACCESS1-3___rcp45.nc ./CHEYENNE_LOCA___ACCESS1-3___rcp45.nc
# -------------------------------
# ./CHEYENNE_LOCA___CCSM4___rcp45.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___CCSM4___rcp45.nc ./CHEYENNE_LOCA___CCSM4___rcp45.nc
# -------------------------------
# ./CHEYENNE_LOCA___CESM1-BGC___rcp45.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___CESM1-BGC___rcp45.nc ./CHEYENNE_LOCA___CESM1-BGC___rcp45.nc
# -------------------------------
# ./CHEYENNE_LOCA___CESM1-CAM5___rcp45.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___CESM1-CAM5___rcp45.nc ./CHEYENNE_LOCA___CESM1-CAM5___rcp45.nc
# -------------------------------
# ./CHEYENNE_LOCA___CMCC-CMS___rcp45.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___CMCC-CMS___rcp45.nc ./CHEYENNE_LOCA___CMCC-CMS___rcp45.nc
# -------------------------------
# ./CHEYENNE_LOCA___CMCC-CM___rcp45.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___CMCC-CM___rcp45.nc ./CHEYENNE_LOCA___CMCC-CM___rcp45.nc
# -------------------------------
# ./CHEYENNE_LOCA___CNRM-CM5___rcp45.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___CNRM-CM5___rcp45.nc ./CHEYENNE_LOCA___CNRM-CM5___rcp45.nc
# -------------------------------
# ./CHEYENNE_LOCA___CSIRO-Mk3-6-0___rcp45.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___CSIRO-Mk3-6-0___rcp45.nc ./CHEYENNE_LOCA___CSIRO-Mk3-6-0___rcp45.nc
# -------------------------------
# ./CHEYENNE_LOCA___CanESM2___rcp45.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___CanESM2___rcp45.nc ./CHEYENNE_LOCA___CanESM2___rcp45.nc
# -------------------------------
# ./CHEYENNE_LOCA___FGOALS-g2___rcp45.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___FGOALS-g2___rcp45.nc ./CHEYENNE_LOCA___FGOALS-g2___rcp45.nc
# -------------------------------
# ./CHEYENNE_LOCA___GFDL-CM3___rcp45.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___GFDL-CM3___rcp45.nc ./CHEYENNE_LOCA___GFDL-CM3___rcp45.nc
# -------------------------------
# ./CHEYENNE_LOCA___GFDL-ESM2G___rcp45.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___GFDL-ESM2G___rcp45.nc ./CHEYENNE_LOCA___GFDL-ESM2G___rcp45.nc
# -------------------------------
# ./CHEYENNE_LOCA___GFDL-ESM2M___rcp45.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___GFDL-ESM2M___rcp45.nc ./CHEYENNE_LOCA___GFDL-ESM2M___rcp45.nc
# -------------------------------
# ./CHEYENNE_LOCA___HadGEM2-AO___rcp45.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___HadGEM2-AO___rcp45.nc ./CHEYENNE_LOCA___HadGEM2-AO___rcp45.nc
# -------------------------------
# ./CHEYENNE_LOCA___HadGEM2-CC___rcp45.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___HadGEM2-CC___rcp45.nc ./CHEYENNE_LOCA___HadGEM2-CC___rcp45.nc
# -------------------------------
# ./CHEYENNE_LOCA___HadGEM2-ES___rcp45.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___HadGEM2-ES___rcp45.nc ./CHEYENNE_LOCA___HadGEM2-ES___rcp45.nc
# -------------------------------
# ./CHEYENNE_LOCA___IPSL-CM5A-LR___rcp45.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___IPSL-CM5A-LR___rcp45.nc ./CHEYENNE_LOCA___IPSL-CM5A-LR___rcp45.nc
# -------------------------------
# ./CHEYENNE_LOCA___IPSL-CM5A-MR___rcp45.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___IPSL-CM5A-MR___rcp45.nc ./CHEYENNE_LOCA___IPSL-CM5A-MR___rcp45.nc
# -------------------------------
# ./CHEYENNE_LOCA___MIROC-ESM-CHEM___rcp45.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___MIROC-ESM-CHEM___rcp45.nc ./CHEYENNE_LOCA___MIROC-ESM-CHEM___rcp45.nc
# -------------------------------
# ./CHEYENNE_LOCA___MIROC-ESM___rcp45.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___MIROC-ESM___rcp45.nc ./CHEYENNE_LOCA___MIROC-ESM___rcp45.nc
# -------------------------------
# ./CHEYENNE_LOCA___MIROC5___rcp45.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___MIROC5___rcp45.nc ./CHEYENNE_LOCA___MIROC5___rcp45.nc
# -------------------------------
# ./CHEYENNE_LOCA___MPI-ESM-LR___rcp45.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___MPI-ESM-LR___rcp45.nc ./CHEYENNE_LOCA___MPI-ESM-LR___rcp45.nc
# -------------------------------
# ./CHEYENNE_LOCA___MPI-ESM-MR___rcp45.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___MPI-ESM-MR___rcp45.nc ./CHEYENNE_LOCA___MPI-ESM-MR___rcp45.nc
# -------------------------------
# ./CHEYENNE_LOCA___MRI-CGCM3___rcp45.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___MRI-CGCM3___rcp45.nc ./CHEYENNE_LOCA___MRI-CGCM3___rcp45.nc
# -------------------------------
# ./CHEYENNE_LOCA___NorESM1-M___rcp45.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___NorESM1-M___rcp45.nc ./CHEYENNE_LOCA___NorESM1-M___rcp45.nc
# -------------------------------
# ./CHEYENNE_LOCA___bcc-csm1-1-m___rcp45.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___bcc-csm1-1-m___rcp45.nc ./CHEYENNE_LOCA___bcc-csm1-1-m___rcp45.nc
# ===============================
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85
# -------------------------------
# ./CHEYENNE_LOCA___ACCESS1-0___rcp85.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___ACCESS1-0___rcp85.nc ./CHEYENNE_LOCA___ACCESS1-0___rcp85.nc
# -------------------------------
# ./CHEYENNE_LOCA___ACCESS1-3___rcp85.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___ACCESS1-3___rcp85.nc ./CHEYENNE_LOCA___ACCESS1-3___rcp85.nc
# -------------------------------
# ./CHEYENNE_LOCA___CCSM4___rcp85.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___CCSM4___rcp85.nc ./CHEYENNE_LOCA___CCSM4___rcp85.nc
# -------------------------------
# ./CHEYENNE_LOCA___CESM1-BGC___rcp85.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___CESM1-BGC___rcp85.nc ./CHEYENNE_LOCA___CESM1-BGC___rcp85.nc
# -------------------------------
# ./CHEYENNE_LOCA___CESM1-CAM5___rcp85.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___CESM1-CAM5___rcp85.nc ./CHEYENNE_LOCA___CESM1-CAM5___rcp85.nc
# -------------------------------
# ./CHEYENNE_LOCA___CMCC-CMS___rcp85.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___CMCC-CMS___rcp85.nc ./CHEYENNE_LOCA___CMCC-CMS___rcp85.nc
# -------------------------------
# ./CHEYENNE_LOCA___CMCC-CM___rcp85.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___CMCC-CM___rcp85.nc ./CHEYENNE_LOCA___CMCC-CM___rcp85.nc
# -------------------------------
# ./CHEYENNE_LOCA___CNRM-CM5___rcp85.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___CNRM-CM5___rcp85.nc ./CHEYENNE_LOCA___CNRM-CM5___rcp85.nc
# -------------------------------
# ./CHEYENNE_LOCA___CSIRO-Mk3-6-0___rcp85.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___CSIRO-Mk3-6-0___rcp85.nc ./CHEYENNE_LOCA___CSIRO-Mk3-6-0___rcp85.nc
# -------------------------------
# ./CHEYENNE_LOCA___CanESM2___rcp85.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___CanESM2___rcp85.nc ./CHEYENNE_LOCA___CanESM2___rcp85.nc
# -------------------------------
# ./CHEYENNE_LOCA___FGOALS-g2___rcp85.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___FGOALS-g2___rcp85.nc ./CHEYENNE_LOCA___FGOALS-g2___rcp85.nc
# -------------------------------
# ./CHEYENNE_LOCA___GFDL-CM3___rcp85.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___GFDL-CM3___rcp85.nc ./CHEYENNE_LOCA___GFDL-CM3___rcp85.nc
# -------------------------------
# ./CHEYENNE_LOCA___GFDL-ESM2G___rcp85.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___GFDL-ESM2G___rcp85.nc ./CHEYENNE_LOCA___GFDL-ESM2G___rcp85.nc
# -------------------------------
# ./CHEYENNE_LOCA___GFDL-ESM2M___rcp85.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___GFDL-ESM2M___rcp85.nc ./CHEYENNE_LOCA___GFDL-ESM2M___rcp85.nc
# -------------------------------
# ./CHEYENNE_LOCA___HadGEM2-AO___rcp85.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___HadGEM2-AO___rcp85.nc ./CHEYENNE_LOCA___HadGEM2-AO___rcp85.nc
# -------------------------------
# ./CHEYENNE_LOCA___HadGEM2-CC___rcp85.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___HadGEM2-CC___rcp85.nc ./CHEYENNE_LOCA___HadGEM2-CC___rcp85.nc
# -------------------------------
# ./CHEYENNE_LOCA___HadGEM2-ES___rcp85.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___HadGEM2-ES___rcp85.nc ./CHEYENNE_LOCA___HadGEM2-ES___rcp85.nc
# -------------------------------
# ./CHEYENNE_LOCA___IPSL-CM5A-LR___rcp85.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___IPSL-CM5A-LR___rcp85.nc ./CHEYENNE_LOCA___IPSL-CM5A-LR___rcp85.nc
# -------------------------------
# ./CHEYENNE_LOCA___IPSL-CM5A-MR___rcp85.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___IPSL-CM5A-MR___rcp85.nc ./CHEYENNE_LOCA___IPSL-CM5A-MR___rcp85.nc
# -------------------------------
# ./CHEYENNE_LOCA___MIROC-ESM-CHEM___rcp85.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___MIROC-ESM-CHEM___rcp85.nc ./CHEYENNE_LOCA___MIROC-ESM-CHEM___rcp85.nc
# -------------------------------
# ./CHEYENNE_LOCA___MIROC-ESM___rcp85.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___MIROC-ESM___rcp85.nc ./CHEYENNE_LOCA___MIROC-ESM___rcp85.nc
# -------------------------------
# ./CHEYENNE_LOCA___MIROC5___rcp85.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___MIROC5___rcp85.nc ./CHEYENNE_LOCA___MIROC5___rcp85.nc
# -------------------------------
# ./CHEYENNE_LOCA___MPI-ESM-LR___rcp85.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___MPI-ESM-LR___rcp85.nc ./CHEYENNE_LOCA___MPI-ESM-LR___rcp85.nc
# -------------------------------
# ./CHEYENNE_LOCA___MPI-ESM-MR___rcp85.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___MPI-ESM-MR___rcp85.nc ./CHEYENNE_LOCA___MPI-ESM-MR___rcp85.nc
# -------------------------------
# ./CHEYENNE_LOCA___MRI-CGCM3___rcp85.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___MRI-CGCM3___rcp85.nc ./CHEYENNE_LOCA___MRI-CGCM3___rcp85.nc
# -------------------------------
# ./CHEYENNE_LOCA___NorESM1-M___rcp85.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___NorESM1-M___rcp85.nc ./CHEYENNE_LOCA___NorESM1-M___rcp85.nc
# -------------------------------
# ./CHEYENNE_LOCA___bcc-csm1-1-m___rcp85.nc
# - - - - - - - - - - - - - - - -
#
# ncea -h -4 -d lat,139,180 -d lon,131,209 ./NGP_LOCA___bcc-csm1-1-m___rcp85.nc ./CHEYENNE_LOCA___bcc-csm1-1-m___rcp85.nc
