# %% [markdown]
# # Renaming LOCA Repositories

# %% [markdown]
# ## Libraries

# %%
import os    as os

import numpy as np

# %% [markdown]
# ## Control Variables and Arrays

# %%
working_directory = "./"

ftp_prefix = "http://loca.ucsd.edu/public/LOCA_relative_humid_v2/"

thredds_root = "/projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/"

rcps      = ["historical","rcp45","rcp85"]

variables = ["tasmax", "tasmin", "pr", "rhmin", "rhmax"]

ensembles =  ["ACCESS1-0" ,     \
              "ACCESS1-3",      \
              "CCSM4",          \
              "CESM1-BGC",      \
              "CESM1-CAM5",     \
              "CMCC-CMS",       \
              "CMCC-CM",        \
              "CNRM-CM5",       \
              "CSIRO-Mk3-6-0",  \
              "CanESM2",        \
              "FGOALS-g2",      \
              "GFDL-CM3",       \
              "GFDL-ESM2G",     \
              "GFDL-ESM2M",     \
              "HadGEM2-AO",     \
              "HadGEM2-CC",     \
              "HadGEM2-ES",     \
              "IPSL-CM5A-LR",   \
              "IPSL-CM5A-MR",   \
              "MIROC-ESM-CHEM", \
              "MIROC-ESM",      \
              "MIROC5",         \
              "MPI-ESM-LR",     \
              "MPI-ESM-MR",     \
              "MRI-CGCM3",      \
              "NorESM1-M",      \
              "bcc-csm1-1-m"    ]

ensemble2s = ["ACCESS1-0_r1i1p1" ,     \
              "ACCESS1-3_r1i1p1",      \
              "CCSM4_r6i1p1",          \
              "CESM1-BGC_r1i1p1",      \
              "CESM1-CAM5_r1i1p1",     \
              "CMCC-CMS_r1i1p1",       \
              "CMCC-CM_r1i1p1",        \
              "CNRM-CM5_r1i1p1",       \
              "CSIRO-Mk3-6-0_r1i1p1",  \
              "CanESM2_r1i1p1",        \
              "FGOALS-g2_r1i1p1",      \
              "GFDL-CM3_r1i1p1",       \
              "GFDL-ESM2G_r1i1p1",     \
              "GFDL-ESM2M_r1i1p1",     \
              "HadGEM2-AO_r1i1p1",     \
              "HadGEM2-CC_r1i1p1",     \
              "HadGEM2-ES_r1i1p1",     \
              "IPSL-CM5A-LR_r1i1p1",   \
              "IPSL-CM5A-MR_r1i1p1",   \
              "MIROC-ESM-CHEM_r1i1p1", \
              "MIROC-ESM_r1i1p1",      \
              "MIROC5_r1i1p1",         \
              "MPI-ESM-LR_r1i1p1",     \
              "MPI-ESM-MR_r1i1p1",     \
              "MRI-CGCM3_r1i1p1",      \
              "NorESM1-M_r1i1p1",      \
              "bcc-csm1-1-m_r1i1p1"    ]

# %% [markdown]
# ## Processing Loop

# %%
for variable_new in variables:
    
    print(' ')
    print(' ')
    print('===============================')
    
    for rcp in rcps:
        
        directory = thredds_root + rcp + "/" + variable_new 
        print("cd " + directory)
        os.chdir(directory)

        for ens_j in range(len(ensembles)):
            
            print('-------------------------------')

            ensemble_new = ensembles[ens_j]
            ensemble_old = ensemble2s[ens_j]
            
            variable_old = variable_new + "_" + ensemble_old + "_" + rcp 

            output_file_nc_name_old = "NGP_LOCA"   + \
                                      "_"          + \
                                      variable_new +  \
                                      "_"          + \
                                      ensemble_old + \
                                      "_"          + \
                                      rcp          + \
                                      ".nc"

            output_file_nc_name_new = "NGP_LOCA"    + \
                                      "___"          + \
                                      variable_new  + \
                                      "___"          + \
                                      ensemble_new  + \
                                      "___"          + \
                                      rcp           + \
                                      ".nc"
            
            full_file_nc_name_old = "./" + output_file_nc_name_old
            full_file_nc_name_new = "./" + output_file_nc_name_new
            
            print(output_file_nc_name_old)
            print(output_file_nc_name_new)
            
            if ((variable_new != "rhmin") and (variable_new != "rhmax")) :
            
                print('- - - - - - - - - - - - - - - -')

                print('ncrename -O -h -v ' + variable_old + ',' + variable_new + ' ' + full_file_nc_name_old)
                os.system(" ncrename -O -h -v ' + variable_old + ',' + variable_new + ' ' + full_file_nc_name_old)
                print('ncatted -O -h -a geospatial_lat_min,global,o,f,33.9375   ' + full_file_nc_name_old)
                os.system(" ncatted -O -h -a geospatial_lat_min,global,o,f,33.9375   ' + full_file_nc_name_old)
                print('ncatted -O -h -a geospatial_lat_max,global,o,f,52.8125   ' + full_file_nc_name_old)
                os.system(" ncatted -O -h -a geospatial_lat_max,global,o,f,52.8125   ' + full_file_nc_name_old)
                print('ncatted -O -h -a geospatial_lon_min,global,o,f,-114.3125 ' + full_file_nc_name_old)
                os.system(" ncatted -O -h -a geospatial_lon_min,global,o,f,-114.3125 ' + full_file_nc_name_old)
                print('ncatted -O -h -a geospatial_lon_max,global,o,f,-86.1875  ' + full_file_nc_name_old)
                os.system(" ncatted -O -h -a geospatial_lon_max,global,o,f,-86.1875  ' + full_file_nc_name_old)



                 
            else:
                
                print('- - - - - - - - - - - - - - - -')
                
                print('ncatted -O -h -a title,global,c,c,"Historical LOCA Statistical Downscaling (Localized Constructed Analogs) Statistically downscaled CMIP5 climate projections for North America" ' + full_file_nc_name_old)
                os.system(" ncatted -O -h -a title,global,c,c,"Historical LOCA Statistical Downscaling (Localized Constructed Analogs) Statistically downscaled CMIP5 climate projections for North America" ' + full_file_nc_name_old)
                print('ncatted -O -h -a acknowledgment,global,c,c,"Pierce, D. W. and D. R. Cayan, 2015: Downscaling humidity with Localized Constructed Analogs (LOCA) over the conterminous United States. Climate Dynamics, DOI 10.1007/s00382-015-2845-1" ' + full_file_nc_name_old)
                os.system(" ncatted -O -h -a acknowledgment,global,c,c,"Pierce, D. W. and D. R. Cayan, 2015: Downscaling humidity with Localized Constructed Analogs (LOCA) over the conterminous United States. Climate Dynamics, DOI 10.1007/s00382-015-2845-1" ' + full_file_nc_name_old)
                print('ncatted -O -h -a summary,global,c,c,"LOCA is a statistical downscaling technique that uses past history to add improved fine-scale detail to global climate models. We have used LOCA to downscale 32 global climate models from the CMIP5 archive at a 1/16th degree spatial resolution, covering North America from central Mexico through Southern Canada. The historical period is 1950-2005, and there are two future scenarios available: RCP 4.5 and RCP 8.5 over the period 2006-2100 (although some models stop in 2099). The variables currently available are daily minimum and maximum temperature, and daily precipitation. For more information visit: http://loca.ucsd.edu/" ' + full_file_nc_name_old)
                os.system(" ncatted -O -h -a summary,global,c,c,"LOCA is a statistical downscaling technique that uses past history to add improved fine-scale detail to global climate models. We have used LOCA to downscale 32 global climate models from the CMIP5 archive at a 1/16th degree spatial resolution, covering North America from central Mexico through Southern Canada. The historical period is 1950-2005, and there are two future scenarios available: RCP 4.5 and RCP 8.5 over the period 2006-2100 (although some models stop in 2099). The variables currently available are daily minimum and maximum temperature, and daily precipitation. For more information visit: http://loca.ucsd.edu/" ' + full_file_nc_name_old)
                print('ncatted -O -h -a keywords,global,c,c,"precipitation, temperature, relative_humidity" ' + full_file_nc_name_old)
                os.system(" ncatted -O -h -a keywords,global,c,c,"precipitation, temperature, relative_humidity" ' + full_file_nc_name_old)
                print('ncatted -O -h -a cdm_data_type,global,c,c,"Grid" ' + full_file_nc_name_old)
                os.system(" ncatted -O -h -a cdm_data_type,global,c,c,"Grid" ' + full_file_nc_name_old)
                print('ncatted -O -h -a creator_name,global,c,c,"David Pierce" ' + full_file_nc_name_old)
                os.system(" ncatted -O -h -a creator_name,global,c,c,"David Pierce" ' + full_file_nc_name_old)
                print('ncatted -O -h -a creator_email,global,c,c,"dpierce@ucsd.edu" ' + full_file_nc_name_old)
                os.system(" ncatted -O -h -a creator_email,global,c,c,"dpierce@ucsd.edu" ' + full_file_nc_name_old)
                print('ncatted -O -h -a geospatial_lat_min,global,c,f,33.9375   ' + full_file_nc_name_old)
                os.system(" ncatted -O -h -a geospatial_lat_min,global,c,f,33.9375   ' + full_file_nc_name_old)
                print('ncatted -O -h -a geospatial_lat_max,global,c,f,52.8125   ' + full_file_nc_name_old)
                os.system(" ncatted -O -h -a geospatial_lat_max,global,c,f,52.8125   ' + full_file_nc_name_old)
                print('ncatted -O -h -a geospatial_lon_min,global,c,f,-114.3125 ' + full_file_nc_name_old)
                os.system(" ncatted -O -h -a geospatial_lon_min,global,c,f,-114.3125 ' + full_file_nc_name_old)
                print('ncatted -O -h -a geospatial_lon_max,global,c,f,-86.1875  ' + full_file_nc_name_old)
                os.system(" ncatted -O -h -a geospatial_lon_max,global,c,f,-86.1875  ' + full_file_nc_name_old)


            print('- - - - - - - - - - - - - - - -')

            print(" ncatted -O -h -a SCENARIO,global,c,c,"' + rcp + '" ' + full_file_nc_name_old)
            os.system(" ncatted -O -h -a SCENARIO,global,c,c,"' + rcp + '" ' + full_file_nc_name_old)

            print('- - - - - - - - - - - - - - - -')

            print(" ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"' + ensemble_old + '" ' + full_file_nc_name_old)
            os.system(" ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"' + ensemble_old + '" ' + full_file_nc_name_old)

            print('- - - - - - - - - - - - - - - -')

            print("ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"' + ensemble_new + '" ' + full_file_nc_name_old)
            os.system(" ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"' + ensemble_new + '" ' + full_file_nc_name_old)

            print('- - - - - - - - - - - - - - - -')

            print("mv -v ' + full_file_nc_name_old + ' ' + full_file_nc_name_new)
            os.system(" mv -v ' + full_file_nc_name_old + ' ' + full_file_nc_name_new)
           
    print('===============================')
    print(' ')
    print(' ')
# Out:
#
#
# ===============================
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical/tasmax
# -------------------------------
# NGP_LOCA_tasmax_ACCESS1-0_r1i1p1_historical.nc
# NGP_LOCA___tasmax___ACCESS1-0___historical.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_ACCESS1-0_r1i1p1_historical,tasmax ./NGP_LOCA_tasmax_ACCESS1-0_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"historical" ./NGP_LOCA_tasmax_ACCESS1-0_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"ACCESS1-0_r1i1p1" ./NGP_LOCA_tasmax_ACCESS1-0_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"ACCESS1-0" ./NGP_LOCA_tasmax_ACCESS1-0_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_ACCESS1-0_r1i1p1_historical.nc ./NGP_LOCA___tasmax___ACCESS1-0___historical.nc
# -------------------------------
# NGP_LOCA_tasmax_ACCESS1-3_r1i1p1_historical.nc
# NGP_LOCA___tasmax___ACCESS1-3___historical.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_ACCESS1-3_r1i1p1_historical,tasmax ./NGP_LOCA_tasmax_ACCESS1-3_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"historical" ./NGP_LOCA_tasmax_ACCESS1-3_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"ACCESS1-3_r1i1p1" ./NGP_LOCA_tasmax_ACCESS1-3_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"ACCESS1-3" ./NGP_LOCA_tasmax_ACCESS1-3_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_ACCESS1-3_r1i1p1_historical.nc ./NGP_LOCA___tasmax___ACCESS1-3___historical.nc
# -------------------------------
# NGP_LOCA_tasmax_CCSM4_r6i1p1_historical.nc
# NGP_LOCA___tasmax___CCSM4___historical.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_CCSM4_r6i1p1_historical,tasmax ./NGP_LOCA_tasmax_CCSM4_r6i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"historical" ./NGP_LOCA_tasmax_CCSM4_r6i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"CCSM4_r6i1p1" ./NGP_LOCA_tasmax_CCSM4_r6i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"CCSM4" ./NGP_LOCA_tasmax_CCSM4_r6i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_CCSM4_r6i1p1_historical.nc ./NGP_LOCA___tasmax___CCSM4___historical.nc
# -------------------------------
# NGP_LOCA_tasmax_CESM1-BGC_r1i1p1_historical.nc
# NGP_LOCA___tasmax___CESM1-BGC___historical.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_CESM1-BGC_r1i1p1_historical,tasmax ./NGP_LOCA_tasmax_CESM1-BGC_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"historical" ./NGP_LOCA_tasmax_CESM1-BGC_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"CESM1-BGC_r1i1p1" ./NGP_LOCA_tasmax_CESM1-BGC_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"CESM1-BGC" ./NGP_LOCA_tasmax_CESM1-BGC_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_CESM1-BGC_r1i1p1_historical.nc ./NGP_LOCA___tasmax___CESM1-BGC___historical.nc
# -------------------------------
# NGP_LOCA_tasmax_CESM1-CAM5_r1i1p1_historical.nc
# NGP_LOCA___tasmax___CESM1-CAM5___historical.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_CESM1-CAM5_r1i1p1_historical,tasmax ./NGP_LOCA_tasmax_CESM1-CAM5_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"historical" ./NGP_LOCA_tasmax_CESM1-CAM5_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"CESM1-CAM5_r1i1p1" ./NGP_LOCA_tasmax_CESM1-CAM5_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"CESM1-CAM5" ./NGP_LOCA_tasmax_CESM1-CAM5_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_CESM1-CAM5_r1i1p1_historical.nc ./NGP_LOCA___tasmax___CESM1-CAM5___historical.nc
# -------------------------------
# NGP_LOCA_tasmax_CMCC-CMS_r1i1p1_historical.nc
# NGP_LOCA___tasmax___CMCC-CMS___historical.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_CMCC-CMS_r1i1p1_historical,tasmax ./NGP_LOCA_tasmax_CMCC-CMS_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"historical" ./NGP_LOCA_tasmax_CMCC-CMS_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"CMCC-CMS_r1i1p1" ./NGP_LOCA_tasmax_CMCC-CMS_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"CMCC-CMS" ./NGP_LOCA_tasmax_CMCC-CMS_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_CMCC-CMS_r1i1p1_historical.nc ./NGP_LOCA___tasmax___CMCC-CMS___historical.nc
# -------------------------------
# NGP_LOCA_tasmax_CMCC-CM_r1i1p1_historical.nc
# NGP_LOCA___tasmax___CMCC-CM___historical.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_CMCC-CM_r1i1p1_historical,tasmax ./NGP_LOCA_tasmax_CMCC-CM_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"historical" ./NGP_LOCA_tasmax_CMCC-CM_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"CMCC-CM_r1i1p1" ./NGP_LOCA_tasmax_CMCC-CM_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"CMCC-CM" ./NGP_LOCA_tasmax_CMCC-CM_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_CMCC-CM_r1i1p1_historical.nc ./NGP_LOCA___tasmax___CMCC-CM___historical.nc
# -------------------------------
# NGP_LOCA_tasmax_CNRM-CM5_r1i1p1_historical.nc
# NGP_LOCA___tasmax___CNRM-CM5___historical.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_CNRM-CM5_r1i1p1_historical,tasmax ./NGP_LOCA_tasmax_CNRM-CM5_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"historical" ./NGP_LOCA_tasmax_CNRM-CM5_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"CNRM-CM5_r1i1p1" ./NGP_LOCA_tasmax_CNRM-CM5_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"CNRM-CM5" ./NGP_LOCA_tasmax_CNRM-CM5_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_CNRM-CM5_r1i1p1_historical.nc ./NGP_LOCA___tasmax___CNRM-CM5___historical.nc
# -------------------------------
# NGP_LOCA_tasmax_CSIRO-Mk3-6-0_r1i1p1_historical.nc
# NGP_LOCA___tasmax___CSIRO-Mk3-6-0___historical.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_CSIRO-Mk3-6-0_r1i1p1_historical,tasmax ./NGP_LOCA_tasmax_CSIRO-Mk3-6-0_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"historical" ./NGP_LOCA_tasmax_CSIRO-Mk3-6-0_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"CSIRO-Mk3-6-0_r1i1p1" ./NGP_LOCA_tasmax_CSIRO-Mk3-6-0_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"CSIRO-Mk3-6-0" ./NGP_LOCA_tasmax_CSIRO-Mk3-6-0_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_CSIRO-Mk3-6-0_r1i1p1_historical.nc ./NGP_LOCA___tasmax___CSIRO-Mk3-6-0___historical.nc
# -------------------------------
# NGP_LOCA_tasmax_CanESM2_r1i1p1_historical.nc
# NGP_LOCA___tasmax___CanESM2___historical.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_CanESM2_r1i1p1_historical,tasmax ./NGP_LOCA_tasmax_CanESM2_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"historical" ./NGP_LOCA_tasmax_CanESM2_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"CanESM2_r1i1p1" ./NGP_LOCA_tasmax_CanESM2_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"CanESM2" ./NGP_LOCA_tasmax_CanESM2_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_CanESM2_r1i1p1_historical.nc ./NGP_LOCA___tasmax___CanESM2___historical.nc
# -------------------------------
# NGP_LOCA_tasmax_FGOALS-g2_r1i1p1_historical.nc
# NGP_LOCA___tasmax___FGOALS-g2___historical.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_FGOALS-g2_r1i1p1_historical,tasmax ./NGP_LOCA_tasmax_FGOALS-g2_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"historical" ./NGP_LOCA_tasmax_FGOALS-g2_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"FGOALS-g2_r1i1p1" ./NGP_LOCA_tasmax_FGOALS-g2_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"FGOALS-g2" ./NGP_LOCA_tasmax_FGOALS-g2_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_FGOALS-g2_r1i1p1_historical.nc ./NGP_LOCA___tasmax___FGOALS-g2___historical.nc
# -------------------------------
# NGP_LOCA_tasmax_GFDL-CM3_r1i1p1_historical.nc
# NGP_LOCA___tasmax___GFDL-CM3___historical.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_GFDL-CM3_r1i1p1_historical,tasmax ./NGP_LOCA_tasmax_GFDL-CM3_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"historical" ./NGP_LOCA_tasmax_GFDL-CM3_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"GFDL-CM3_r1i1p1" ./NGP_LOCA_tasmax_GFDL-CM3_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"GFDL-CM3" ./NGP_LOCA_tasmax_GFDL-CM3_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_GFDL-CM3_r1i1p1_historical.nc ./NGP_LOCA___tasmax___GFDL-CM3___historical.nc
# -------------------------------
# NGP_LOCA_tasmax_GFDL-ESM2G_r1i1p1_historical.nc
# NGP_LOCA___tasmax___GFDL-ESM2G___historical.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_GFDL-ESM2G_r1i1p1_historical,tasmax ./NGP_LOCA_tasmax_GFDL-ESM2G_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"historical" ./NGP_LOCA_tasmax_GFDL-ESM2G_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"GFDL-ESM2G_r1i1p1" ./NGP_LOCA_tasmax_GFDL-ESM2G_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"GFDL-ESM2G" ./NGP_LOCA_tasmax_GFDL-ESM2G_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_GFDL-ESM2G_r1i1p1_historical.nc ./NGP_LOCA___tasmax___GFDL-ESM2G___historical.nc
# -------------------------------
# NGP_LOCA_tasmax_GFDL-ESM2M_r1i1p1_historical.nc
# NGP_LOCA___tasmax___GFDL-ESM2M___historical.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_GFDL-ESM2M_r1i1p1_historical,tasmax ./NGP_LOCA_tasmax_GFDL-ESM2M_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"historical" ./NGP_LOCA_tasmax_GFDL-ESM2M_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"GFDL-ESM2M_r1i1p1" ./NGP_LOCA_tasmax_GFDL-ESM2M_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"GFDL-ESM2M" ./NGP_LOCA_tasmax_GFDL-ESM2M_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_GFDL-ESM2M_r1i1p1_historical.nc ./NGP_LOCA___tasmax___GFDL-ESM2M___historical.nc
# -------------------------------
# NGP_LOCA_tasmax_HadGEM2-AO_r1i1p1_historical.nc
# NGP_LOCA___tasmax___HadGEM2-AO___historical.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_HadGEM2-AO_r1i1p1_historical,tasmax ./NGP_LOCA_tasmax_HadGEM2-AO_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"historical" ./NGP_LOCA_tasmax_HadGEM2-AO_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"HadGEM2-AO_r1i1p1" ./NGP_LOCA_tasmax_HadGEM2-AO_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"HadGEM2-AO" ./NGP_LOCA_tasmax_HadGEM2-AO_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_HadGEM2-AO_r1i1p1_historical.nc ./NGP_LOCA___tasmax___HadGEM2-AO___historical.nc
# -------------------------------
# NGP_LOCA_tasmax_HadGEM2-CC_r1i1p1_historical.nc
# NGP_LOCA___tasmax___HadGEM2-CC___historical.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_HadGEM2-CC_r1i1p1_historical,tasmax ./NGP_LOCA_tasmax_HadGEM2-CC_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"historical" ./NGP_LOCA_tasmax_HadGEM2-CC_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"HadGEM2-CC_r1i1p1" ./NGP_LOCA_tasmax_HadGEM2-CC_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"HadGEM2-CC" ./NGP_LOCA_tasmax_HadGEM2-CC_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_HadGEM2-CC_r1i1p1_historical.nc ./NGP_LOCA___tasmax___HadGEM2-CC___historical.nc
# -------------------------------
# NGP_LOCA_tasmax_HadGEM2-ES_r1i1p1_historical.nc
# NGP_LOCA___tasmax___HadGEM2-ES___historical.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_HadGEM2-ES_r1i1p1_historical,tasmax ./NGP_LOCA_tasmax_HadGEM2-ES_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"historical" ./NGP_LOCA_tasmax_HadGEM2-ES_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"HadGEM2-ES_r1i1p1" ./NGP_LOCA_tasmax_HadGEM2-ES_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"HadGEM2-ES" ./NGP_LOCA_tasmax_HadGEM2-ES_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_HadGEM2-ES_r1i1p1_historical.nc ./NGP_LOCA___tasmax___HadGEM2-ES___historical.nc
# -------------------------------
# NGP_LOCA_tasmax_IPSL-CM5A-LR_r1i1p1_historical.nc
# NGP_LOCA___tasmax___IPSL-CM5A-LR___historical.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_IPSL-CM5A-LR_r1i1p1_historical,tasmax ./NGP_LOCA_tasmax_IPSL-CM5A-LR_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"historical" ./NGP_LOCA_tasmax_IPSL-CM5A-LR_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"IPSL-CM5A-LR_r1i1p1" ./NGP_LOCA_tasmax_IPSL-CM5A-LR_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"IPSL-CM5A-LR" ./NGP_LOCA_tasmax_IPSL-CM5A-LR_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_IPSL-CM5A-LR_r1i1p1_historical.nc ./NGP_LOCA___tasmax___IPSL-CM5A-LR___historical.nc
# -------------------------------
# NGP_LOCA_tasmax_IPSL-CM5A-MR_r1i1p1_historical.nc
# NGP_LOCA___tasmax___IPSL-CM5A-MR___historical.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_IPSL-CM5A-MR_r1i1p1_historical,tasmax ./NGP_LOCA_tasmax_IPSL-CM5A-MR_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"historical" ./NGP_LOCA_tasmax_IPSL-CM5A-MR_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"IPSL-CM5A-MR_r1i1p1" ./NGP_LOCA_tasmax_IPSL-CM5A-MR_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"IPSL-CM5A-MR" ./NGP_LOCA_tasmax_IPSL-CM5A-MR_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_IPSL-CM5A-MR_r1i1p1_historical.nc ./NGP_LOCA___tasmax___IPSL-CM5A-MR___historical.nc
# -------------------------------
# NGP_LOCA_tasmax_MIROC-ESM-CHEM_r1i1p1_historical.nc
# NGP_LOCA___tasmax___MIROC-ESM-CHEM___historical.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_MIROC-ESM-CHEM_r1i1p1_historical,tasmax ./NGP_LOCA_tasmax_MIROC-ESM-CHEM_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"historical" ./NGP_LOCA_tasmax_MIROC-ESM-CHEM_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"MIROC-ESM-CHEM_r1i1p1" ./NGP_LOCA_tasmax_MIROC-ESM-CHEM_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"MIROC-ESM-CHEM" ./NGP_LOCA_tasmax_MIROC-ESM-CHEM_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_MIROC-ESM-CHEM_r1i1p1_historical.nc ./NGP_LOCA___tasmax___MIROC-ESM-CHEM___historical.nc
# -------------------------------
# NGP_LOCA_tasmax_MIROC-ESM_r1i1p1_historical.nc
# NGP_LOCA___tasmax___MIROC-ESM___historical.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_MIROC-ESM_r1i1p1_historical,tasmax ./NGP_LOCA_tasmax_MIROC-ESM_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"historical" ./NGP_LOCA_tasmax_MIROC-ESM_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"MIROC-ESM_r1i1p1" ./NGP_LOCA_tasmax_MIROC-ESM_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"MIROC-ESM" ./NGP_LOCA_tasmax_MIROC-ESM_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_MIROC-ESM_r1i1p1_historical.nc ./NGP_LOCA___tasmax___MIROC-ESM___historical.nc
# -------------------------------
# NGP_LOCA_tasmax_MIROC5_r1i1p1_historical.nc
# NGP_LOCA___tasmax___MIROC5___historical.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_MIROC5_r1i1p1_historical,tasmax ./NGP_LOCA_tasmax_MIROC5_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"historical" ./NGP_LOCA_tasmax_MIROC5_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"MIROC5_r1i1p1" ./NGP_LOCA_tasmax_MIROC5_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"MIROC5" ./NGP_LOCA_tasmax_MIROC5_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_MIROC5_r1i1p1_historical.nc ./NGP_LOCA___tasmax___MIROC5___historical.nc
# -------------------------------
# NGP_LOCA_tasmax_MPI-ESM-LR_r1i1p1_historical.nc
# NGP_LOCA___tasmax___MPI-ESM-LR___historical.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_MPI-ESM-LR_r1i1p1_historical,tasmax ./NGP_LOCA_tasmax_MPI-ESM-LR_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"historical" ./NGP_LOCA_tasmax_MPI-ESM-LR_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"MPI-ESM-LR_r1i1p1" ./NGP_LOCA_tasmax_MPI-ESM-LR_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"MPI-ESM-LR" ./NGP_LOCA_tasmax_MPI-ESM-LR_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_MPI-ESM-LR_r1i1p1_historical.nc ./NGP_LOCA___tasmax___MPI-ESM-LR___historical.nc
# -------------------------------
# NGP_LOCA_tasmax_MPI-ESM-MR_r1i1p1_historical.nc
# NGP_LOCA___tasmax___MPI-ESM-MR___historical.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_MPI-ESM-MR_r1i1p1_historical,tasmax ./NGP_LOCA_tasmax_MPI-ESM-MR_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"historical" ./NGP_LOCA_tasmax_MPI-ESM-MR_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"MPI-ESM-MR_r1i1p1" ./NGP_LOCA_tasmax_MPI-ESM-MR_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"MPI-ESM-MR" ./NGP_LOCA_tasmax_MPI-ESM-MR_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_MPI-ESM-MR_r1i1p1_historical.nc ./NGP_LOCA___tasmax___MPI-ESM-MR___historical.nc
# -------------------------------
# NGP_LOCA_tasmax_MRI-CGCM3_r1i1p1_historical.nc
# NGP_LOCA___tasmax___MRI-CGCM3___historical.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_MRI-CGCM3_r1i1p1_historical,tasmax ./NGP_LOCA_tasmax_MRI-CGCM3_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"historical" ./NGP_LOCA_tasmax_MRI-CGCM3_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"MRI-CGCM3_r1i1p1" ./NGP_LOCA_tasmax_MRI-CGCM3_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"MRI-CGCM3" ./NGP_LOCA_tasmax_MRI-CGCM3_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_MRI-CGCM3_r1i1p1_historical.nc ./NGP_LOCA___tasmax___MRI-CGCM3___historical.nc
# -------------------------------
# NGP_LOCA_tasmax_NorESM1-M_r1i1p1_historical.nc
# NGP_LOCA___tasmax___NorESM1-M___historical.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_NorESM1-M_r1i1p1_historical,tasmax ./NGP_LOCA_tasmax_NorESM1-M_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"historical" ./NGP_LOCA_tasmax_NorESM1-M_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"NorESM1-M_r1i1p1" ./NGP_LOCA_tasmax_NorESM1-M_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"NorESM1-M" ./NGP_LOCA_tasmax_NorESM1-M_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_NorESM1-M_r1i1p1_historical.nc ./NGP_LOCA___tasmax___NorESM1-M___historical.nc
# -------------------------------
# NGP_LOCA_tasmax_bcc-csm1-1-m_r1i1p1_historical.nc
# NGP_LOCA___tasmax___bcc-csm1-1-m___historical.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_bcc-csm1-1-m_r1i1p1_historical,tasmax ./NGP_LOCA_tasmax_bcc-csm1-1-m_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"historical" ./NGP_LOCA_tasmax_bcc-csm1-1-m_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"bcc-csm1-1-m_r1i1p1" ./NGP_LOCA_tasmax_bcc-csm1-1-m_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"bcc-csm1-1-m" ./NGP_LOCA_tasmax_bcc-csm1-1-m_r1i1p1_historical.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_bcc-csm1-1-m_r1i1p1_historical.nc ./NGP_LOCA___tasmax___bcc-csm1-1-m___historical.nc
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45/tasmax
# -------------------------------
# NGP_LOCA_tasmax_ACCESS1-0_r1i1p1_rcp45.nc
# NGP_LOCA___tasmax___ACCESS1-0___rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_ACCESS1-0_r1i1p1_rcp45,tasmax ./NGP_LOCA_tasmax_ACCESS1-0_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"rcp45" ./NGP_LOCA_tasmax_ACCESS1-0_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"ACCESS1-0_r1i1p1" ./NGP_LOCA_tasmax_ACCESS1-0_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"ACCESS1-0" ./NGP_LOCA_tasmax_ACCESS1-0_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_ACCESS1-0_r1i1p1_rcp45.nc ./NGP_LOCA___tasmax___ACCESS1-0___rcp45.nc
# -------------------------------
# NGP_LOCA_tasmax_ACCESS1-3_r1i1p1_rcp45.nc
# NGP_LOCA___tasmax___ACCESS1-3___rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_ACCESS1-3_r1i1p1_rcp45,tasmax ./NGP_LOCA_tasmax_ACCESS1-3_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"rcp45" ./NGP_LOCA_tasmax_ACCESS1-3_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"ACCESS1-3_r1i1p1" ./NGP_LOCA_tasmax_ACCESS1-3_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"ACCESS1-3" ./NGP_LOCA_tasmax_ACCESS1-3_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_ACCESS1-3_r1i1p1_rcp45.nc ./NGP_LOCA___tasmax___ACCESS1-3___rcp45.nc
# -------------------------------
# NGP_LOCA_tasmax_CCSM4_r6i1p1_rcp45.nc
# NGP_LOCA___tasmax___CCSM4___rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_CCSM4_r6i1p1_rcp45,tasmax ./NGP_LOCA_tasmax_CCSM4_r6i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"rcp45" ./NGP_LOCA_tasmax_CCSM4_r6i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"CCSM4_r6i1p1" ./NGP_LOCA_tasmax_CCSM4_r6i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"CCSM4" ./NGP_LOCA_tasmax_CCSM4_r6i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_CCSM4_r6i1p1_rcp45.nc ./NGP_LOCA___tasmax___CCSM4___rcp45.nc
# -------------------------------
# NGP_LOCA_tasmax_CESM1-BGC_r1i1p1_rcp45.nc
# NGP_LOCA___tasmax___CESM1-BGC___rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_CESM1-BGC_r1i1p1_rcp45,tasmax ./NGP_LOCA_tasmax_CESM1-BGC_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"rcp45" ./NGP_LOCA_tasmax_CESM1-BGC_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"CESM1-BGC_r1i1p1" ./NGP_LOCA_tasmax_CESM1-BGC_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"CESM1-BGC" ./NGP_LOCA_tasmax_CESM1-BGC_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_CESM1-BGC_r1i1p1_rcp45.nc ./NGP_LOCA___tasmax___CESM1-BGC___rcp45.nc
# -------------------------------
# NGP_LOCA_tasmax_CESM1-CAM5_r1i1p1_rcp45.nc
# NGP_LOCA___tasmax___CESM1-CAM5___rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_CESM1-CAM5_r1i1p1_rcp45,tasmax ./NGP_LOCA_tasmax_CESM1-CAM5_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"rcp45" ./NGP_LOCA_tasmax_CESM1-CAM5_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"CESM1-CAM5_r1i1p1" ./NGP_LOCA_tasmax_CESM1-CAM5_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"CESM1-CAM5" ./NGP_LOCA_tasmax_CESM1-CAM5_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_CESM1-CAM5_r1i1p1_rcp45.nc ./NGP_LOCA___tasmax___CESM1-CAM5___rcp45.nc
# -------------------------------
# NGP_LOCA_tasmax_CMCC-CMS_r1i1p1_rcp45.nc
# NGP_LOCA___tasmax___CMCC-CMS___rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_CMCC-CMS_r1i1p1_rcp45,tasmax ./NGP_LOCA_tasmax_CMCC-CMS_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"rcp45" ./NGP_LOCA_tasmax_CMCC-CMS_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"CMCC-CMS_r1i1p1" ./NGP_LOCA_tasmax_CMCC-CMS_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"CMCC-CMS" ./NGP_LOCA_tasmax_CMCC-CMS_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_CMCC-CMS_r1i1p1_rcp45.nc ./NGP_LOCA___tasmax___CMCC-CMS___rcp45.nc
# -------------------------------
# NGP_LOCA_tasmax_CMCC-CM_r1i1p1_rcp45.nc
# NGP_LOCA___tasmax___CMCC-CM___rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_CMCC-CM_r1i1p1_rcp45,tasmax ./NGP_LOCA_tasmax_CMCC-CM_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"rcp45" ./NGP_LOCA_tasmax_CMCC-CM_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"CMCC-CM_r1i1p1" ./NGP_LOCA_tasmax_CMCC-CM_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"CMCC-CM" ./NGP_LOCA_tasmax_CMCC-CM_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_CMCC-CM_r1i1p1_rcp45.nc ./NGP_LOCA___tasmax___CMCC-CM___rcp45.nc
# -------------------------------
# NGP_LOCA_tasmax_CNRM-CM5_r1i1p1_rcp45.nc
# NGP_LOCA___tasmax___CNRM-CM5___rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_CNRM-CM5_r1i1p1_rcp45,tasmax ./NGP_LOCA_tasmax_CNRM-CM5_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"rcp45" ./NGP_LOCA_tasmax_CNRM-CM5_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"CNRM-CM5_r1i1p1" ./NGP_LOCA_tasmax_CNRM-CM5_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"CNRM-CM5" ./NGP_LOCA_tasmax_CNRM-CM5_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_CNRM-CM5_r1i1p1_rcp45.nc ./NGP_LOCA___tasmax___CNRM-CM5___rcp45.nc
# -------------------------------
# NGP_LOCA_tasmax_CSIRO-Mk3-6-0_r1i1p1_rcp45.nc
# NGP_LOCA___tasmax___CSIRO-Mk3-6-0___rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_CSIRO-Mk3-6-0_r1i1p1_rcp45,tasmax ./NGP_LOCA_tasmax_CSIRO-Mk3-6-0_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"rcp45" ./NGP_LOCA_tasmax_CSIRO-Mk3-6-0_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"CSIRO-Mk3-6-0_r1i1p1" ./NGP_LOCA_tasmax_CSIRO-Mk3-6-0_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"CSIRO-Mk3-6-0" ./NGP_LOCA_tasmax_CSIRO-Mk3-6-0_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_CSIRO-Mk3-6-0_r1i1p1_rcp45.nc ./NGP_LOCA___tasmax___CSIRO-Mk3-6-0___rcp45.nc
# -------------------------------
# NGP_LOCA_tasmax_CanESM2_r1i1p1_rcp45.nc
# NGP_LOCA___tasmax___CanESM2___rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_CanESM2_r1i1p1_rcp45,tasmax ./NGP_LOCA_tasmax_CanESM2_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"rcp45" ./NGP_LOCA_tasmax_CanESM2_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"CanESM2_r1i1p1" ./NGP_LOCA_tasmax_CanESM2_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"CanESM2" ./NGP_LOCA_tasmax_CanESM2_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_CanESM2_r1i1p1_rcp45.nc ./NGP_LOCA___tasmax___CanESM2___rcp45.nc
# -------------------------------
# NGP_LOCA_tasmax_FGOALS-g2_r1i1p1_rcp45.nc
# NGP_LOCA___tasmax___FGOALS-g2___rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_FGOALS-g2_r1i1p1_rcp45,tasmax ./NGP_LOCA_tasmax_FGOALS-g2_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"rcp45" ./NGP_LOCA_tasmax_FGOALS-g2_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"FGOALS-g2_r1i1p1" ./NGP_LOCA_tasmax_FGOALS-g2_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"FGOALS-g2" ./NGP_LOCA_tasmax_FGOALS-g2_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_FGOALS-g2_r1i1p1_rcp45.nc ./NGP_LOCA___tasmax___FGOALS-g2___rcp45.nc
# -------------------------------
# NGP_LOCA_tasmax_GFDL-CM3_r1i1p1_rcp45.nc
# NGP_LOCA___tasmax___GFDL-CM3___rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_GFDL-CM3_r1i1p1_rcp45,tasmax ./NGP_LOCA_tasmax_GFDL-CM3_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"rcp45" ./NGP_LOCA_tasmax_GFDL-CM3_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"GFDL-CM3_r1i1p1" ./NGP_LOCA_tasmax_GFDL-CM3_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"GFDL-CM3" ./NGP_LOCA_tasmax_GFDL-CM3_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_GFDL-CM3_r1i1p1_rcp45.nc ./NGP_LOCA___tasmax___GFDL-CM3___rcp45.nc
# -------------------------------
# NGP_LOCA_tasmax_GFDL-ESM2G_r1i1p1_rcp45.nc
# NGP_LOCA___tasmax___GFDL-ESM2G___rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_GFDL-ESM2G_r1i1p1_rcp45,tasmax ./NGP_LOCA_tasmax_GFDL-ESM2G_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"rcp45" ./NGP_LOCA_tasmax_GFDL-ESM2G_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"GFDL-ESM2G_r1i1p1" ./NGP_LOCA_tasmax_GFDL-ESM2G_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"GFDL-ESM2G" ./NGP_LOCA_tasmax_GFDL-ESM2G_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_GFDL-ESM2G_r1i1p1_rcp45.nc ./NGP_LOCA___tasmax___GFDL-ESM2G___rcp45.nc
# -------------------------------
# NGP_LOCA_tasmax_GFDL-ESM2M_r1i1p1_rcp45.nc
# NGP_LOCA___tasmax___GFDL-ESM2M___rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_GFDL-ESM2M_r1i1p1_rcp45,tasmax ./NGP_LOCA_tasmax_GFDL-ESM2M_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"rcp45" ./NGP_LOCA_tasmax_GFDL-ESM2M_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"GFDL-ESM2M_r1i1p1" ./NGP_LOCA_tasmax_GFDL-ESM2M_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"GFDL-ESM2M" ./NGP_LOCA_tasmax_GFDL-ESM2M_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_GFDL-ESM2M_r1i1p1_rcp45.nc ./NGP_LOCA___tasmax___GFDL-ESM2M___rcp45.nc
# -------------------------------
# NGP_LOCA_tasmax_HadGEM2-AO_r1i1p1_rcp45.nc
# NGP_LOCA___tasmax___HadGEM2-AO___rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_HadGEM2-AO_r1i1p1_rcp45,tasmax ./NGP_LOCA_tasmax_HadGEM2-AO_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"rcp45" ./NGP_LOCA_tasmax_HadGEM2-AO_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"HadGEM2-AO_r1i1p1" ./NGP_LOCA_tasmax_HadGEM2-AO_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"HadGEM2-AO" ./NGP_LOCA_tasmax_HadGEM2-AO_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_HadGEM2-AO_r1i1p1_rcp45.nc ./NGP_LOCA___tasmax___HadGEM2-AO___rcp45.nc
# -------------------------------
# NGP_LOCA_tasmax_HadGEM2-CC_r1i1p1_rcp45.nc
# NGP_LOCA___tasmax___HadGEM2-CC___rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_HadGEM2-CC_r1i1p1_rcp45,tasmax ./NGP_LOCA_tasmax_HadGEM2-CC_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"rcp45" ./NGP_LOCA_tasmax_HadGEM2-CC_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"HadGEM2-CC_r1i1p1" ./NGP_LOCA_tasmax_HadGEM2-CC_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"HadGEM2-CC" ./NGP_LOCA_tasmax_HadGEM2-CC_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_HadGEM2-CC_r1i1p1_rcp45.nc ./NGP_LOCA___tasmax___HadGEM2-CC___rcp45.nc
# -------------------------------
# NGP_LOCA_tasmax_HadGEM2-ES_r1i1p1_rcp45.nc
# NGP_LOCA___tasmax___HadGEM2-ES___rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_HadGEM2-ES_r1i1p1_rcp45,tasmax ./NGP_LOCA_tasmax_HadGEM2-ES_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"rcp45" ./NGP_LOCA_tasmax_HadGEM2-ES_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"HadGEM2-ES_r1i1p1" ./NGP_LOCA_tasmax_HadGEM2-ES_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"HadGEM2-ES" ./NGP_LOCA_tasmax_HadGEM2-ES_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_HadGEM2-ES_r1i1p1_rcp45.nc ./NGP_LOCA___tasmax___HadGEM2-ES___rcp45.nc
# -------------------------------
# NGP_LOCA_tasmax_IPSL-CM5A-LR_r1i1p1_rcp45.nc
# NGP_LOCA___tasmax___IPSL-CM5A-LR___rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_IPSL-CM5A-LR_r1i1p1_rcp45,tasmax ./NGP_LOCA_tasmax_IPSL-CM5A-LR_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"rcp45" ./NGP_LOCA_tasmax_IPSL-CM5A-LR_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"IPSL-CM5A-LR_r1i1p1" ./NGP_LOCA_tasmax_IPSL-CM5A-LR_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"IPSL-CM5A-LR" ./NGP_LOCA_tasmax_IPSL-CM5A-LR_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_IPSL-CM5A-LR_r1i1p1_rcp45.nc ./NGP_LOCA___tasmax___IPSL-CM5A-LR___rcp45.nc
# -------------------------------
# NGP_LOCA_tasmax_IPSL-CM5A-MR_r1i1p1_rcp45.nc
# NGP_LOCA___tasmax___IPSL-CM5A-MR___rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_IPSL-CM5A-MR_r1i1p1_rcp45,tasmax ./NGP_LOCA_tasmax_IPSL-CM5A-MR_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"rcp45" ./NGP_LOCA_tasmax_IPSL-CM5A-MR_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"IPSL-CM5A-MR_r1i1p1" ./NGP_LOCA_tasmax_IPSL-CM5A-MR_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"IPSL-CM5A-MR" ./NGP_LOCA_tasmax_IPSL-CM5A-MR_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_IPSL-CM5A-MR_r1i1p1_rcp45.nc ./NGP_LOCA___tasmax___IPSL-CM5A-MR___rcp45.nc
# -------------------------------
# NGP_LOCA_tasmax_MIROC-ESM-CHEM_r1i1p1_rcp45.nc
# NGP_LOCA___tasmax___MIROC-ESM-CHEM___rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_MIROC-ESM-CHEM_r1i1p1_rcp45,tasmax ./NGP_LOCA_tasmax_MIROC-ESM-CHEM_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"rcp45" ./NGP_LOCA_tasmax_MIROC-ESM-CHEM_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"MIROC-ESM-CHEM_r1i1p1" ./NGP_LOCA_tasmax_MIROC-ESM-CHEM_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"MIROC-ESM-CHEM" ./NGP_LOCA_tasmax_MIROC-ESM-CHEM_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_MIROC-ESM-CHEM_r1i1p1_rcp45.nc ./NGP_LOCA___tasmax___MIROC-ESM-CHEM___rcp45.nc
# -------------------------------
# NGP_LOCA_tasmax_MIROC-ESM_r1i1p1_rcp45.nc
# NGP_LOCA___tasmax___MIROC-ESM___rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_MIROC-ESM_r1i1p1_rcp45,tasmax ./NGP_LOCA_tasmax_MIROC-ESM_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"rcp45" ./NGP_LOCA_tasmax_MIROC-ESM_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"MIROC-ESM_r1i1p1" ./NGP_LOCA_tasmax_MIROC-ESM_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"MIROC-ESM" ./NGP_LOCA_tasmax_MIROC-ESM_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_MIROC-ESM_r1i1p1_rcp45.nc ./NGP_LOCA___tasmax___MIROC-ESM___rcp45.nc
# -------------------------------
# NGP_LOCA_tasmax_MIROC5_r1i1p1_rcp45.nc
# NGP_LOCA___tasmax___MIROC5___rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_MIROC5_r1i1p1_rcp45,tasmax ./NGP_LOCA_tasmax_MIROC5_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"rcp45" ./NGP_LOCA_tasmax_MIROC5_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"MIROC5_r1i1p1" ./NGP_LOCA_tasmax_MIROC5_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"MIROC5" ./NGP_LOCA_tasmax_MIROC5_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_MIROC5_r1i1p1_rcp45.nc ./NGP_LOCA___tasmax___MIROC5___rcp45.nc
# -------------------------------
# NGP_LOCA_tasmax_MPI-ESM-LR_r1i1p1_rcp45.nc
# NGP_LOCA___tasmax___MPI-ESM-LR___rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_MPI-ESM-LR_r1i1p1_rcp45,tasmax ./NGP_LOCA_tasmax_MPI-ESM-LR_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"rcp45" ./NGP_LOCA_tasmax_MPI-ESM-LR_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"MPI-ESM-LR_r1i1p1" ./NGP_LOCA_tasmax_MPI-ESM-LR_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"MPI-ESM-LR" ./NGP_LOCA_tasmax_MPI-ESM-LR_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_MPI-ESM-LR_r1i1p1_rcp45.nc ./NGP_LOCA___tasmax___MPI-ESM-LR___rcp45.nc
# -------------------------------
# NGP_LOCA_tasmax_MPI-ESM-MR_r1i1p1_rcp45.nc
# NGP_LOCA___tasmax___MPI-ESM-MR___rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_MPI-ESM-MR_r1i1p1_rcp45,tasmax ./NGP_LOCA_tasmax_MPI-ESM-MR_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"rcp45" ./NGP_LOCA_tasmax_MPI-ESM-MR_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"MPI-ESM-MR_r1i1p1" ./NGP_LOCA_tasmax_MPI-ESM-MR_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"MPI-ESM-MR" ./NGP_LOCA_tasmax_MPI-ESM-MR_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_MPI-ESM-MR_r1i1p1_rcp45.nc ./NGP_LOCA___tasmax___MPI-ESM-MR___rcp45.nc
# -------------------------------
# NGP_LOCA_tasmax_MRI-CGCM3_r1i1p1_rcp45.nc
# NGP_LOCA___tasmax___MRI-CGCM3___rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_MRI-CGCM3_r1i1p1_rcp45,tasmax ./NGP_LOCA_tasmax_MRI-CGCM3_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"rcp45" ./NGP_LOCA_tasmax_MRI-CGCM3_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"MRI-CGCM3_r1i1p1" ./NGP_LOCA_tasmax_MRI-CGCM3_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"MRI-CGCM3" ./NGP_LOCA_tasmax_MRI-CGCM3_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_MRI-CGCM3_r1i1p1_rcp45.nc ./NGP_LOCA___tasmax___MRI-CGCM3___rcp45.nc
# -------------------------------
# NGP_LOCA_tasmax_NorESM1-M_r1i1p1_rcp45.nc
# NGP_LOCA___tasmax___NorESM1-M___rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_NorESM1-M_r1i1p1_rcp45,tasmax ./NGP_LOCA_tasmax_NorESM1-M_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"rcp45" ./NGP_LOCA_tasmax_NorESM1-M_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"NorESM1-M_r1i1p1" ./NGP_LOCA_tasmax_NorESM1-M_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"NorESM1-M" ./NGP_LOCA_tasmax_NorESM1-M_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_NorESM1-M_r1i1p1_rcp45.nc ./NGP_LOCA___tasmax___NorESM1-M___rcp45.nc
# -------------------------------
# NGP_LOCA_tasmax_bcc-csm1-1-m_r1i1p1_rcp45.nc
# NGP_LOCA___tasmax___bcc-csm1-1-m___rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_bcc-csm1-1-m_r1i1p1_rcp45,tasmax ./NGP_LOCA_tasmax_bcc-csm1-1-m_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"rcp45" ./NGP_LOCA_tasmax_bcc-csm1-1-m_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"bcc-csm1-1-m_r1i1p1" ./NGP_LOCA_tasmax_bcc-csm1-1-m_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"bcc-csm1-1-m" ./NGP_LOCA_tasmax_bcc-csm1-1-m_r1i1p1_rcp45.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_bcc-csm1-1-m_r1i1p1_rcp45.nc ./NGP_LOCA___tasmax___bcc-csm1-1-m___rcp45.nc
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85/tasmax
# -------------------------------
# NGP_LOCA_tasmax_ACCESS1-0_r1i1p1_rcp85.nc
# NGP_LOCA___tasmax___ACCESS1-0___rcp85.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_ACCESS1-0_r1i1p1_rcp85,tasmax ./NGP_LOCA_tasmax_ACCESS1-0_r1i1p1_rcp85.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"rcp85" ./NGP_LOCA_tasmax_ACCESS1-0_r1i1p1_rcp85.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"ACCESS1-0_r1i1p1" ./NGP_LOCA_tasmax_ACCESS1-0_r1i1p1_rcp85.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"ACCESS1-0" ./NGP_LOCA_tasmax_ACCESS1-0_r1i1p1_rcp85.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_ACCESS1-0_r1i1p1_rcp85.nc ./NGP_LOCA___tasmax___ACCESS1-0___rcp85.nc
# -------------------------------
# NGP_LOCA_tasmax_ACCESS1-3_r1i1p1_rcp85.nc
# NGP_LOCA___tasmax___ACCESS1-3___rcp85.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_ACCESS1-3_r1i1p1_rcp85,tasmax ./NGP_LOCA_tasmax_ACCESS1-3_r1i1p1_rcp85.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"rcp85" ./NGP_LOCA_tasmax_ACCESS1-3_r1i1p1_rcp85.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"ACCESS1-3_r1i1p1" ./NGP_LOCA_tasmax_ACCESS1-3_r1i1p1_rcp85.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"ACCESS1-3" ./NGP_LOCA_tasmax_ACCESS1-3_r1i1p1_rcp85.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_ACCESS1-3_r1i1p1_rcp85.nc ./NGP_LOCA___tasmax___ACCESS1-3___rcp85.nc
# -------------------------------
# NGP_LOCA_tasmax_CCSM4_r6i1p1_rcp85.nc
# NGP_LOCA___tasmax___CCSM4___rcp85.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_CCSM4_r6i1p1_rcp85,tasmax ./NGP_LOCA_tasmax_CCSM4_r6i1p1_rcp85.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"rcp85" ./NGP_LOCA_tasmax_CCSM4_r6i1p1_rcp85.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"CCSM4_r6i1p1" ./NGP_LOCA_tasmax_CCSM4_r6i1p1_rcp85.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"CCSM4" ./NGP_LOCA_tasmax_CCSM4_r6i1p1_rcp85.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_CCSM4_r6i1p1_rcp85.nc ./NGP_LOCA___tasmax___CCSM4___rcp85.nc
# -------------------------------
# NGP_LOCA_tasmax_CESM1-BGC_r1i1p1_rcp85.nc
# NGP_LOCA___tasmax___CESM1-BGC___rcp85.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_CESM1-BGC_r1i1p1_rcp85,tasmax ./NGP_LOCA_tasmax_CESM1-BGC_r1i1p1_rcp85.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"rcp85" ./NGP_LOCA_tasmax_CESM1-BGC_r1i1p1_rcp85.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"CESM1-BGC_r1i1p1" ./NGP_LOCA_tasmax_CESM1-BGC_r1i1p1_rcp85.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"CESM1-BGC" ./NGP_LOCA_tasmax_CESM1-BGC_r1i1p1_rcp85.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_CESM1-BGC_r1i1p1_rcp85.nc ./NGP_LOCA___tasmax___CESM1-BGC___rcp85.nc
# -------------------------------
# NGP_LOCA_tasmax_CESM1-CAM5_r1i1p1_rcp85.nc
# NGP_LOCA___tasmax___CESM1-CAM5___rcp85.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_CESM1-CAM5_r1i1p1_rcp85,tasmax ./NGP_LOCA_tasmax_CESM1-CAM5_r1i1p1_rcp85.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"rcp85" ./NGP_LOCA_tasmax_CESM1-CAM5_r1i1p1_rcp85.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"CESM1-CAM5_r1i1p1" ./NGP_LOCA_tasmax_CESM1-CAM5_r1i1p1_rcp85.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"CESM1-CAM5" ./NGP_LOCA_tasmax_CESM1-CAM5_r1i1p1_rcp85.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_tasmax_CESM1-CAM5_r1i1p1_rcp85.nc ./NGP_LOCA___tasmax___CESM1-CAM5___rcp85.nc
# -------------------------------
# NGP_LOCA_tasmax_CMCC-CMS_r1i1p1_rcp85.nc
# NGP_LOCA___tasmax___CMCC-CMS___rcp85.nc
# - - - - - - - - - - - - - - - -
# ## ncrename -O -h -v tasmax_CMCC-CMS_r1i1p1_rcp85,tasmax ./NGP_LOCA_tasmax_CMCC-CMS_r1i1p1_rcp85.nc
# - - - - - - - - - - - - - - - -
# ...
# NGP_LOCA_rhmax_MPI-ESM-LR_r1i1p1_rcp85.nc
# NGP_LOCA___rhmax___MPI-ESM-LR___rcp85.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a title,global,c,c,"Historical LOCA Statistical Downscaling (Localized Constructed Analogs) Statistically downscaled CMIP5 climate projections for North America" ./NGP_LOCA_rhmax_MPI-ESM-LR_r1i1p1_rcp85.nc
# ## ncatted -O -h -a acknowledgment,global,c,c,"Pierce, D. W., D. R. Cayan, and B. L. Thrasher, 2014: Statistical downscaling using Localized Constructed Analogs (LOCA). Journal of Hydrometeorology, volume 15, page 2558-2585. We acknowledge the World Climate Research Programme's Working Group on Coupled Modeling, which is responsible for CMIP, and we thank the climate modeling groups for producing and making available their model output. For CMIP, the U.S. Department of Energy's Program for Climate Model Diagnosis and Intercomparison provides coordinating support and led development of software infrastructure in partnership with the Global Organization for Earth System Science Portals." ./NGP_LOCA_rhmax_MPI-ESM-LR_r1i1p1_rcp85.nc
# ## ncatted -O -h -a summary,global,c,c,"LOCA is a statistical downscaling technique that uses past history to add improved fine-scale detail to global climate models. We have used LOCA to downscale 32 global climate models from the CMIP5 archive at a 1/16th degree spatial resolution, covering North America from central Mexico through Southern Canada. The historical period is 1950-2005, and there are two future scenarios available: RCP 4.5 and RCP 8.5 over the period 2006-2100 (although some models stop in 2099). The variables currently available are daily minimum and maximum temperature, and daily precipitation. For more information visit: http://loca.ucsd.edu/" ./NGP_LOCA_rhmax_MPI-ESM-LR_r1i1p1_rcp85.nc
# ## ncatted -O -h -a keywords,global,c,c,"precipitation, temperature, relative_humidity" ./NGP_LOCA_rhmax_MPI-ESM-LR_r1i1p1_rcp85.nc
# ## ncatted -O -h -a cdm_data_type,global,c,c,"Grid" ./NGP_LOCA_rhmax_MPI-ESM-LR_r1i1p1_rcp85.nc
# ## ncatted -O -h -a creator_name,global,c,c,"David Pierce" ./NGP_LOCA_rhmax_MPI-ESM-LR_r1i1p1_rcp85.nc
# ## ncatted -O -h -a creator_email,global,c,c,"dpierce@ucsd.edu" ./NGP_LOCA_rhmax_MPI-ESM-LR_r1i1p1_rcp85.nc
# ## ncatted -O -h -a geospatial_lat_min,global,c,c,"24"   ./NGP_LOCA_rhmax_MPI-ESM-LR_r1i1p1_rcp85.nc
# ## ncatted -O -h -a geospatial_lat_max,global,c,c,"53"   ./NGP_LOCA_rhmax_MPI-ESM-LR_r1i1p1_rcp85.nc
# ## ncatted -O -h -a geospatial_lon_min,global,c,c,"-125" ./NGP_LOCA_rhmax_MPI-ESM-LR_r1i1p1_rcp85.nc
# ## ncatted -O -h -a geospatial_lon_max,global,c,c,"-67"  ./NGP_LOCA_rhmax_MPI-ESM-LR_r1i1p1_rcp85.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"rcp85" ./NGP_LOCA_rhmax_MPI-ESM-LR_r1i1p1_rcp85.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"MPI-ESM-LR_r1i1p1" ./NGP_LOCA_rhmax_MPI-ESM-LR_r1i1p1_rcp85.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"MPI-ESM-LR" ./NGP_LOCA_rhmax_MPI-ESM-LR_r1i1p1_rcp85.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_rhmax_MPI-ESM-LR_r1i1p1_rcp85.nc ./NGP_LOCA___rhmax___MPI-ESM-LR___rcp85.nc
# -------------------------------
# NGP_LOCA_rhmax_MPI-ESM-MR_r1i1p1_rcp85.nc
# NGP_LOCA___rhmax___MPI-ESM-MR___rcp85.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a title,global,c,c,"Historical LOCA Statistical Downscaling (Localized Constructed Analogs) Statistically downscaled CMIP5 climate projections for North America" ./NGP_LOCA_rhmax_MPI-ESM-MR_r1i1p1_rcp85.nc
# ## ncatted -O -h -a acknowledgment,global,c,c,"Pierce, D. W., D. R. Cayan, and B. L. Thrasher, 2014: Statistical downscaling using Localized Constructed Analogs (LOCA). Journal of Hydrometeorology, volume 15, page 2558-2585. We acknowledge the World Climate Research Programme's Working Group on Coupled Modeling, which is responsible for CMIP, and we thank the climate modeling groups for producing and making available their model output. For CMIP, the U.S. Department of Energy's Program for Climate Model Diagnosis and Intercomparison provides coordinating support and led development of software infrastructure in partnership with the Global Organization for Earth System Science Portals." ./NGP_LOCA_rhmax_MPI-ESM-MR_r1i1p1_rcp85.nc
# ## ncatted -O -h -a summary,global,c,c,"LOCA is a statistical downscaling technique that uses past history to add improved fine-scale detail to global climate models. We have used LOCA to downscale 32 global climate models from the CMIP5 archive at a 1/16th degree spatial resolution, covering North America from central Mexico through Southern Canada. The historical period is 1950-2005, and there are two future scenarios available: RCP 4.5 and RCP 8.5 over the period 2006-2100 (although some models stop in 2099). The variables currently available are daily minimum and maximum temperature, and daily precipitation. For more information visit: http://loca.ucsd.edu/" ./NGP_LOCA_rhmax_MPI-ESM-MR_r1i1p1_rcp85.nc
# ## ncatted -O -h -a keywords,global,c,c,"precipitation, temperature, relative_humidity" ./NGP_LOCA_rhmax_MPI-ESM-MR_r1i1p1_rcp85.nc
# ## ncatted -O -h -a cdm_data_type,global,c,c,"Grid" ./NGP_LOCA_rhmax_MPI-ESM-MR_r1i1p1_rcp85.nc
# ## ncatted -O -h -a creator_name,global,c,c,"David Pierce" ./NGP_LOCA_rhmax_MPI-ESM-MR_r1i1p1_rcp85.nc
# ## ncatted -O -h -a creator_email,global,c,c,"dpierce@ucsd.edu" ./NGP_LOCA_rhmax_MPI-ESM-MR_r1i1p1_rcp85.nc
# ## ncatted -O -h -a geospatial_lat_min,global,c,c,"24"   ./NGP_LOCA_rhmax_MPI-ESM-MR_r1i1p1_rcp85.nc
# ## ncatted -O -h -a geospatial_lat_max,global,c,c,"53"   ./NGP_LOCA_rhmax_MPI-ESM-MR_r1i1p1_rcp85.nc
# ## ncatted -O -h -a geospatial_lon_min,global,c,c,"-125" ./NGP_LOCA_rhmax_MPI-ESM-MR_r1i1p1_rcp85.nc
# ## ncatted -O -h -a geospatial_lon_max,global,c,c,"-67"  ./NGP_LOCA_rhmax_MPI-ESM-MR_r1i1p1_rcp85.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"rcp85" ./NGP_LOCA_rhmax_MPI-ESM-MR_r1i1p1_rcp85.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"MPI-ESM-MR_r1i1p1" ./NGP_LOCA_rhmax_MPI-ESM-MR_r1i1p1_rcp85.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"MPI-ESM-MR" ./NGP_LOCA_rhmax_MPI-ESM-MR_r1i1p1_rcp85.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_rhmax_MPI-ESM-MR_r1i1p1_rcp85.nc ./NGP_LOCA___rhmax___MPI-ESM-MR___rcp85.nc
# -------------------------------
# NGP_LOCA_rhmax_MRI-CGCM3_r1i1p1_rcp85.nc
# NGP_LOCA___rhmax___MRI-CGCM3___rcp85.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a title,global,c,c,"Historical LOCA Statistical Downscaling (Localized Constructed Analogs) Statistically downscaled CMIP5 climate projections for North America" ./NGP_LOCA_rhmax_MRI-CGCM3_r1i1p1_rcp85.nc
# ## ncatted -O -h -a acknowledgment,global,c,c,"Pierce, D. W., D. R. Cayan, and B. L. Thrasher, 2014: Statistical downscaling using Localized Constructed Analogs (LOCA). Journal of Hydrometeorology, volume 15, page 2558-2585. We acknowledge the World Climate Research Programme's Working Group on Coupled Modeling, which is responsible for CMIP, and we thank the climate modeling groups for producing and making available their model output. For CMIP, the U.S. Department of Energy's Program for Climate Model Diagnosis and Intercomparison provides coordinating support and led development of software infrastructure in partnership with the Global Organization for Earth System Science Portals." ./NGP_LOCA_rhmax_MRI-CGCM3_r1i1p1_rcp85.nc
# ## ncatted -O -h -a summary,global,c,c,"LOCA is a statistical downscaling technique that uses past history to add improved fine-scale detail to global climate models. We have used LOCA to downscale 32 global climate models from the CMIP5 archive at a 1/16th degree spatial resolution, covering North America from central Mexico through Southern Canada. The historical period is 1950-2005, and there are two future scenarios available: RCP 4.5 and RCP 8.5 over the period 2006-2100 (although some models stop in 2099). The variables currently available are daily minimum and maximum temperature, and daily precipitation. For more information visit: http://loca.ucsd.edu/" ./NGP_LOCA_rhmax_MRI-CGCM3_r1i1p1_rcp85.nc
# ## ncatted -O -h -a keywords,global,c,c,"precipitation, temperature, relative_humidity" ./NGP_LOCA_rhmax_MRI-CGCM3_r1i1p1_rcp85.nc
# ## ncatted -O -h -a cdm_data_type,global,c,c,"Grid" ./NGP_LOCA_rhmax_MRI-CGCM3_r1i1p1_rcp85.nc
# ## ncatted -O -h -a creator_name,global,c,c,"David Pierce" ./NGP_LOCA_rhmax_MRI-CGCM3_r1i1p1_rcp85.nc
# ## ncatted -O -h -a creator_email,global,c,c,"dpierce@ucsd.edu" ./NGP_LOCA_rhmax_MRI-CGCM3_r1i1p1_rcp85.nc
# ## ncatted -O -h -a geospatial_lat_min,global,c,c,"24"   ./NGP_LOCA_rhmax_MRI-CGCM3_r1i1p1_rcp85.nc
# ## ncatted -O -h -a geospatial_lat_max,global,c,c,"53"   ./NGP_LOCA_rhmax_MRI-CGCM3_r1i1p1_rcp85.nc
# ## ncatted -O -h -a geospatial_lon_min,global,c,c,"-125" ./NGP_LOCA_rhmax_MRI-CGCM3_r1i1p1_rcp85.nc
# ## ncatted -O -h -a geospatial_lon_max,global,c,c,"-67"  ./NGP_LOCA_rhmax_MRI-CGCM3_r1i1p1_rcp85.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"rcp85" ./NGP_LOCA_rhmax_MRI-CGCM3_r1i1p1_rcp85.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"MRI-CGCM3_r1i1p1" ./NGP_LOCA_rhmax_MRI-CGCM3_r1i1p1_rcp85.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"MRI-CGCM3" ./NGP_LOCA_rhmax_MRI-CGCM3_r1i1p1_rcp85.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_rhmax_MRI-CGCM3_r1i1p1_rcp85.nc ./NGP_LOCA___rhmax___MRI-CGCM3___rcp85.nc
# -------------------------------
# NGP_LOCA_rhmax_NorESM1-M_r1i1p1_rcp85.nc
# NGP_LOCA___rhmax___NorESM1-M___rcp85.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a title,global,c,c,"Historical LOCA Statistical Downscaling (Localized Constructed Analogs) Statistically downscaled CMIP5 climate projections for North America" ./NGP_LOCA_rhmax_NorESM1-M_r1i1p1_rcp85.nc
# ## ncatted -O -h -a acknowledgment,global,c,c,"Pierce, D. W., D. R. Cayan, and B. L. Thrasher, 2014: Statistical downscaling using Localized Constructed Analogs (LOCA). Journal of Hydrometeorology, volume 15, page 2558-2585. We acknowledge the World Climate Research Programme's Working Group on Coupled Modeling, which is responsible for CMIP, and we thank the climate modeling groups for producing and making available their model output. For CMIP, the U.S. Department of Energy's Program for Climate Model Diagnosis and Intercomparison provides coordinating support and led development of software infrastructure in partnership with the Global Organization for Earth System Science Portals." ./NGP_LOCA_rhmax_NorESM1-M_r1i1p1_rcp85.nc
# ## ncatted -O -h -a summary,global,c,c,"LOCA is a statistical downscaling technique that uses past history to add improved fine-scale detail to global climate models. We have used LOCA to downscale 32 global climate models from the CMIP5 archive at a 1/16th degree spatial resolution, covering North America from central Mexico through Southern Canada. The historical period is 1950-2005, and there are two future scenarios available: RCP 4.5 and RCP 8.5 over the period 2006-2100 (although some models stop in 2099). The variables currently available are daily minimum and maximum temperature, and daily precipitation. For more information visit: http://loca.ucsd.edu/" ./NGP_LOCA_rhmax_NorESM1-M_r1i1p1_rcp85.nc
# ## ncatted -O -h -a keywords,global,c,c,"precipitation, temperature, relative_humidity" ./NGP_LOCA_rhmax_NorESM1-M_r1i1p1_rcp85.nc
# ## ncatted -O -h -a cdm_data_type,global,c,c,"Grid" ./NGP_LOCA_rhmax_NorESM1-M_r1i1p1_rcp85.nc
# ## ncatted -O -h -a creator_name,global,c,c,"David Pierce" ./NGP_LOCA_rhmax_NorESM1-M_r1i1p1_rcp85.nc
# ## ncatted -O -h -a creator_email,global,c,c,"dpierce@ucsd.edu" ./NGP_LOCA_rhmax_NorESM1-M_r1i1p1_rcp85.nc
# ## ncatted -O -h -a geospatial_lat_min,global,c,c,"24"   ./NGP_LOCA_rhmax_NorESM1-M_r1i1p1_rcp85.nc
# ## ncatted -O -h -a geospatial_lat_max,global,c,c,"53"   ./NGP_LOCA_rhmax_NorESM1-M_r1i1p1_rcp85.nc
# ## ncatted -O -h -a geospatial_lon_min,global,c,c,"-125" ./NGP_LOCA_rhmax_NorESM1-M_r1i1p1_rcp85.nc
# ## ncatted -O -h -a geospatial_lon_max,global,c,c,"-67"  ./NGP_LOCA_rhmax_NorESM1-M_r1i1p1_rcp85.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"rcp85" ./NGP_LOCA_rhmax_NorESM1-M_r1i1p1_rcp85.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"NorESM1-M_r1i1p1" ./NGP_LOCA_rhmax_NorESM1-M_r1i1p1_rcp85.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"NorESM1-M" ./NGP_LOCA_rhmax_NorESM1-M_r1i1p1_rcp85.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_rhmax_NorESM1-M_r1i1p1_rcp85.nc ./NGP_LOCA___rhmax___NorESM1-M___rcp85.nc
# -------------------------------
# NGP_LOCA_rhmax_bcc-csm1-1-m_r1i1p1_rcp85.nc
# NGP_LOCA___rhmax___bcc-csm1-1-m___rcp85.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a title,global,c,c,"Historical LOCA Statistical Downscaling (Localized Constructed Analogs) Statistically downscaled CMIP5 climate projections for North America" ./NGP_LOCA_rhmax_bcc-csm1-1-m_r1i1p1_rcp85.nc
# ## ncatted -O -h -a acknowledgment,global,c,c,"Pierce, D. W., D. R. Cayan, and B. L. Thrasher, 2014: Statistical downscaling using Localized Constructed Analogs (LOCA). Journal of Hydrometeorology, volume 15, page 2558-2585. We acknowledge the World Climate Research Programme's Working Group on Coupled Modeling, which is responsible for CMIP, and we thank the climate modeling groups for producing and making available their model output. For CMIP, the U.S. Department of Energy's Program for Climate Model Diagnosis and Intercomparison provides coordinating support and led development of software infrastructure in partnership with the Global Organization for Earth System Science Portals." ./NGP_LOCA_rhmax_bcc-csm1-1-m_r1i1p1_rcp85.nc
# ## ncatted -O -h -a summary,global,c,c,"LOCA is a statistical downscaling technique that uses past history to add improved fine-scale detail to global climate models. We have used LOCA to downscale 32 global climate models from the CMIP5 archive at a 1/16th degree spatial resolution, covering North America from central Mexico through Southern Canada. The historical period is 1950-2005, and there are two future scenarios available: RCP 4.5 and RCP 8.5 over the period 2006-2100 (although some models stop in 2099). The variables currently available are daily minimum and maximum temperature, and daily precipitation. For more information visit: http://loca.ucsd.edu/" ./NGP_LOCA_rhmax_bcc-csm1-1-m_r1i1p1_rcp85.nc
# ## ncatted -O -h -a keywords,global,c,c,"precipitation, temperature, relative_humidity" ./NGP_LOCA_rhmax_bcc-csm1-1-m_r1i1p1_rcp85.nc
# ## ncatted -O -h -a cdm_data_type,global,c,c,"Grid" ./NGP_LOCA_rhmax_bcc-csm1-1-m_r1i1p1_rcp85.nc
# ## ncatted -O -h -a creator_name,global,c,c,"David Pierce" ./NGP_LOCA_rhmax_bcc-csm1-1-m_r1i1p1_rcp85.nc
# ## ncatted -O -h -a creator_email,global,c,c,"dpierce@ucsd.edu" ./NGP_LOCA_rhmax_bcc-csm1-1-m_r1i1p1_rcp85.nc
# ## ncatted -O -h -a geospatial_lat_min,global,c,c,"24"   ./NGP_LOCA_rhmax_bcc-csm1-1-m_r1i1p1_rcp85.nc
# ## ncatted -O -h -a geospatial_lat_max,global,c,c,"53"   ./NGP_LOCA_rhmax_bcc-csm1-1-m_r1i1p1_rcp85.nc
# ## ncatted -O -h -a geospatial_lon_min,global,c,c,"-125" ./NGP_LOCA_rhmax_bcc-csm1-1-m_r1i1p1_rcp85.nc
# ## ncatted -O -h -a geospatial_lon_max,global,c,c,"-67"  ./NGP_LOCA_rhmax_bcc-csm1-1-m_r1i1p1_rcp85.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a SCENARIO,global,c,c,"rcp85" ./NGP_LOCA_rhmax_bcc-csm1-1-m_r1i1p1_rcp85.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_LONG,global,c,c,"bcc-csm1-1-m_r1i1p1" ./NGP_LOCA_rhmax_bcc-csm1-1-m_r1i1p1_rcp85.nc
# - - - - - - - - - - - - - - - -
# ## ncatted -O -h -a ENSEMBLE_SHORT,global,c,c,"bcc-csm1-1-m" ./NGP_LOCA_rhmax_bcc-csm1-1-m_r1i1p1_rcp85.nc
# - - - - - - - - - - - - - - - -
# ## mv -v ./NGP_LOCA_rhmax_bcc-csm1-1-m_r1i1p1_rcp85.nc ./NGP_LOCA___rhmax___bcc-csm1-1-m___rcp85.nc
# ===============================
