# %%
import os    as os

import numpy as np

# %%
working_directory = "./"

ftp_prefix = "http://loca.ucsd.edu/public/LOCA_relative_humid_v2/"

thredds_root = "/projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/"


rcps      = ["historical","rcp45","rcp85"]

variables = ["rhmin", "rhmax"]


#variables = ["rel_humid_max",
#             "rel_humid_min"]#

ensembles = ['ACCESS1-0',      \
             'ACCESS1-3',      \
             'CCSM4',          \
             'CNRM-CM5',       \
             'CanESM2',        \
             'FGOALS-g2',      \
             'GFDL-CM3',       \
             'GFDL-ESM2G',     \
             'GFDL-ESM2M',     \
             'HadGEM2-AO',     \
             'HadGEM2-CC',     \
             'HadGEM2-ES',     \
             'IPSL-CM5A-LR',   \
             'IPSL-CM5A-MR',   \
             'MIROC-ESM-CHEM', \
             'MIROC-ESM',      \
             'MIROC5',         \
             'MRI-CGCM3',      \
             'NorESM1-M',      \
             'bcc-csm1-1-m']

ensemble2s = ['ACCESS1-0_r1i1p1',      \
             'ACCESS1-3_r1i1p1',      \
             'CCSM4_r6i1p1',          \
             'CNRM-CM5_r1i1p1',       \
             'CanESM2_r1i1p1',        \
             'FGOALS-g2_r1i1p1',      \
             'GFDL-CM3_r1i1p1',       \
             'GFDL-ESM2G_r1i1p1',     \
             'GFDL-ESM2M_r1i1p1',     \
             'HadGEM2-AO_r1i1p1',     \
             'HadGEM2-CC_r1i1p1',     \
             'HadGEM2-ES_r1i1p1',     \
             'IPSL-CM5A-LR_r1i1p1',   \
             'IPSL-CM5A-MR_r1i1p1',   \
             'MIROC-ESM-CHEM_r1i1p1', \
             'MIROC-ESM_r1i1p1',      \
             'MIROC5_r1i1p1',         \
             'MRI-CGCM3_r1i1p1',      \
             'NorESM1-M_r1i1p1',      \
             'bcc-csm1-1-m_r1i1p1']

subset_lon = np.array([-114.28125, -86.21875]) + 360
subset_lat = np.array([  33.96875,  52.78125])

subset_i   = [165,614]
subset_j   = [141,442]


bounds_script_command = 'defdim("bnds",2);time@bounds="time_bnds";time_bnds[$time,$bnds]=0.0;*time_dff=0.5*(time(1)-time(0));time_bnds(:,0)=time-time_dff;time_bnds(:,1)=time+time_dff;lat@bounds="lat_bnds";lat_bnds[$lat,$bnds]=0.0;*lat_dff=0.5*(lat(1)-lat(0));lat_bnds(:,0)=lat-lat_dff;lat_bnds(:,1)=lat+lat_dff;lon@bounds="lat_bnds";lon_bnds[$lon,$bnds]=0.0;*lon_dff=0.5*(lon(1)-lon(0));lon_bnds(:,0)=lon-lon_dff;lon_bnds(:,1)=lon+lon_dff;'

# %% [markdown]
#  File Names:
#
# ```
#
# http://loca.ucsd.edu/public/LOCA_relative_humid_v2/historical/rel_humid_max/rel_humid.ACCESS1-0.historical.1950-2005.4-8_file.rel_humid_max.crop.bc.nc.gz
# rel_humid.ACCESS1-0.historical.1950-2005.4-8_file.rel_humid_min.crop.bc.smv.nc.gz
# rel_humid.ACCESS1-0.rcp45.2006-2100.rel_humid_max.crop.bc.nc.gz
# rel_humid.ACCESS1-0.rcp85.2006-2100.rel_humid_max.crop.bc.nc.gz
#
# NGP_LOCA_tasmin_bcc-csm1-1-m_r1i1p1_rcp85.nc
#
# ```

# %%
variables = ["rhmin", "rhmax"]
variables = ["rhmax"]


for variable in variables:
    for rcp in rcps:
        for ensemble in ensembles:



 


            
            thredds_url_full = ftp_prefix + rcp + "/" + variable + "/"
            
            output_file_nc_name_new = "NGP_LOCA"    + \
                                      "___"          + \
                                      variable  + \
                                      "___"          + \
                                      ensemble  + \
                                      "___"          + \
                                      rcp           + \
                                      ".nc"
            
            print("# ==============================")
            print("# ", output_file_nc_name_new)
            print("# ", thredds_root  + rcp + "/" + variable )
            
            print("cd " + thredds_root  + rcp + "/" + variable )
            
 
            print("# Process ",variable, ensemble, rcp)    
            print("ncap2 -h --deflate 8 -s 'lon=(lon-360)'           " + output_file_nc_name_new + ' temp.nc')
            print("ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc")
            print("mv -vf  temp2.nc " + output_file_nc_name_new)
            print("rm -frv temp.nc temp2.nc")
            print(" ")
# Out:
# # ==============================
# #  NGP_LOCA___rhmax___ACCESS1-0___historical.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical/rhmax
# # Process  rhmax ACCESS1-0 historical
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___ACCESS1-0___historical.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___ACCESS1-0___historical.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___ACCESS1-3___historical.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical/rhmax
# # Process  rhmax ACCESS1-3 historical
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___ACCESS1-3___historical.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___ACCESS1-3___historical.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___CCSM4___historical.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical/rhmax
# # Process  rhmax CCSM4 historical
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___CCSM4___historical.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___CCSM4___historical.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___CNRM-CM5___historical.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical/rhmax
# # Process  rhmax CNRM-CM5 historical
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___CNRM-CM5___historical.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___CNRM-CM5___historical.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___CanESM2___historical.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical/rhmax
# # Process  rhmax CanESM2 historical
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___CanESM2___historical.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___CanESM2___historical.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___FGOALS-g2___historical.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical/rhmax
# # Process  rhmax FGOALS-g2 historical
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___FGOALS-g2___historical.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___FGOALS-g2___historical.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___GFDL-CM3___historical.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical/rhmax
# # Process  rhmax GFDL-CM3 historical
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___GFDL-CM3___historical.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___GFDL-CM3___historical.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___GFDL-ESM2G___historical.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical/rhmax
# # Process  rhmax GFDL-ESM2G historical
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___GFDL-ESM2G___historical.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___GFDL-ESM2G___historical.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___GFDL-ESM2M___historical.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical/rhmax
# # Process  rhmax GFDL-ESM2M historical
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___GFDL-ESM2M___historical.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___GFDL-ESM2M___historical.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___HadGEM2-AO___historical.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical/rhmax
# # Process  rhmax HadGEM2-AO historical
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___HadGEM2-AO___historical.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___HadGEM2-AO___historical.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___HadGEM2-CC___historical.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical/rhmax
# # Process  rhmax HadGEM2-CC historical
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___HadGEM2-CC___historical.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___HadGEM2-CC___historical.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___HadGEM2-ES___historical.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical/rhmax
# # Process  rhmax HadGEM2-ES historical
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___HadGEM2-ES___historical.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___HadGEM2-ES___historical.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___IPSL-CM5A-LR___historical.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical/rhmax
# # Process  rhmax IPSL-CM5A-LR historical
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___IPSL-CM5A-LR___historical.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___IPSL-CM5A-LR___historical.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___IPSL-CM5A-MR___historical.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical/rhmax
# # Process  rhmax IPSL-CM5A-MR historical
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___IPSL-CM5A-MR___historical.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___IPSL-CM5A-MR___historical.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___MIROC-ESM-CHEM___historical.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical/rhmax
# # Process  rhmax MIROC-ESM-CHEM historical
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___MIROC-ESM-CHEM___historical.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___MIROC-ESM-CHEM___historical.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___MIROC-ESM___historical.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical/rhmax
# # Process  rhmax MIROC-ESM historical
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___MIROC-ESM___historical.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___MIROC-ESM___historical.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___MIROC5___historical.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical/rhmax
# # Process  rhmax MIROC5 historical
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___MIROC5___historical.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___MIROC5___historical.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___MRI-CGCM3___historical.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical/rhmax
# # Process  rhmax MRI-CGCM3 historical
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___MRI-CGCM3___historical.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___MRI-CGCM3___historical.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___NorESM1-M___historical.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical/rhmax
# # Process  rhmax NorESM1-M historical
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___NorESM1-M___historical.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___NorESM1-M___historical.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___bcc-csm1-1-m___historical.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/historical/rhmax
# # Process  rhmax bcc-csm1-1-m historical
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___bcc-csm1-1-m___historical.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___bcc-csm1-1-m___historical.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___ACCESS1-0___rcp45.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45/rhmax
# # Process  rhmax ACCESS1-0 rcp45
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___ACCESS1-0___rcp45.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___ACCESS1-0___rcp45.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___ACCESS1-3___rcp45.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45/rhmax
# # Process  rhmax ACCESS1-3 rcp45
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___ACCESS1-3___rcp45.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___ACCESS1-3___rcp45.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___CCSM4___rcp45.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45/rhmax
# # Process  rhmax CCSM4 rcp45
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___CCSM4___rcp45.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___CCSM4___rcp45.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___CNRM-CM5___rcp45.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45/rhmax
# # Process  rhmax CNRM-CM5 rcp45
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___CNRM-CM5___rcp45.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___CNRM-CM5___rcp45.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___CanESM2___rcp45.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45/rhmax
# # Process  rhmax CanESM2 rcp45
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___CanESM2___rcp45.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___CanESM2___rcp45.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___FGOALS-g2___rcp45.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45/rhmax
# # Process  rhmax FGOALS-g2 rcp45
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___FGOALS-g2___rcp45.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___FGOALS-g2___rcp45.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___GFDL-CM3___rcp45.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45/rhmax
# # Process  rhmax GFDL-CM3 rcp45
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___GFDL-CM3___rcp45.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___GFDL-CM3___rcp45.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___GFDL-ESM2G___rcp45.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45/rhmax
# # Process  rhmax GFDL-ESM2G rcp45
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___GFDL-ESM2G___rcp45.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___GFDL-ESM2G___rcp45.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___GFDL-ESM2M___rcp45.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45/rhmax
# # Process  rhmax GFDL-ESM2M rcp45
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___GFDL-ESM2M___rcp45.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___GFDL-ESM2M___rcp45.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___HadGEM2-AO___rcp45.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45/rhmax
# # Process  rhmax HadGEM2-AO rcp45
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___HadGEM2-AO___rcp45.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___HadGEM2-AO___rcp45.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___HadGEM2-CC___rcp45.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45/rhmax
# # Process  rhmax HadGEM2-CC rcp45
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___HadGEM2-CC___rcp45.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___HadGEM2-CC___rcp45.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___HadGEM2-ES___rcp45.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45/rhmax
# # Process  rhmax HadGEM2-ES rcp45
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___HadGEM2-ES___rcp45.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___HadGEM2-ES___rcp45.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___IPSL-CM5A-LR___rcp45.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45/rhmax
# # Process  rhmax IPSL-CM5A-LR rcp45
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___IPSL-CM5A-LR___rcp45.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___IPSL-CM5A-LR___rcp45.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___IPSL-CM5A-MR___rcp45.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45/rhmax
# # Process  rhmax IPSL-CM5A-MR rcp45
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___IPSL-CM5A-MR___rcp45.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___IPSL-CM5A-MR___rcp45.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___MIROC-ESM-CHEM___rcp45.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45/rhmax
# # Process  rhmax MIROC-ESM-CHEM rcp45
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___MIROC-ESM-CHEM___rcp45.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___MIROC-ESM-CHEM___rcp45.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___MIROC-ESM___rcp45.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45/rhmax
# # Process  rhmax MIROC-ESM rcp45
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___MIROC-ESM___rcp45.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___MIROC-ESM___rcp45.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___MIROC5___rcp45.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45/rhmax
# # Process  rhmax MIROC5 rcp45
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___MIROC5___rcp45.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___MIROC5___rcp45.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___MRI-CGCM3___rcp45.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45/rhmax
# # Process  rhmax MRI-CGCM3 rcp45
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___MRI-CGCM3___rcp45.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___MRI-CGCM3___rcp45.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___NorESM1-M___rcp45.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45/rhmax
# # Process  rhmax NorESM1-M rcp45
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___NorESM1-M___rcp45.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___NorESM1-M___rcp45.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___bcc-csm1-1-m___rcp45.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp45/rhmax
# # Process  rhmax bcc-csm1-1-m rcp45
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___bcc-csm1-1-m___rcp45.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___bcc-csm1-1-m___rcp45.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___ACCESS1-0___rcp85.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85/rhmax
# # Process  rhmax ACCESS1-0 rcp85
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___ACCESS1-0___rcp85.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___ACCESS1-0___rcp85.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___ACCESS1-3___rcp85.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85/rhmax
# # Process  rhmax ACCESS1-3 rcp85
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___ACCESS1-3___rcp85.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___ACCESS1-3___rcp85.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___CCSM4___rcp85.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85/rhmax
# # Process  rhmax CCSM4 rcp85
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___CCSM4___rcp85.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___CCSM4___rcp85.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___CNRM-CM5___rcp85.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85/rhmax
# # Process  rhmax CNRM-CM5 rcp85
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___CNRM-CM5___rcp85.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___CNRM-CM5___rcp85.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___CanESM2___rcp85.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85/rhmax
# # Process  rhmax CanESM2 rcp85
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___CanESM2___rcp85.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___CanESM2___rcp85.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___FGOALS-g2___rcp85.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85/rhmax
# # Process  rhmax FGOALS-g2 rcp85
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___FGOALS-g2___rcp85.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___FGOALS-g2___rcp85.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___GFDL-CM3___rcp85.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85/rhmax
# # Process  rhmax GFDL-CM3 rcp85
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___GFDL-CM3___rcp85.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___GFDL-CM3___rcp85.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___GFDL-ESM2G___rcp85.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85/rhmax
# # Process  rhmax GFDL-ESM2G rcp85
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___GFDL-ESM2G___rcp85.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___GFDL-ESM2G___rcp85.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___GFDL-ESM2M___rcp85.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85/rhmax
# # Process  rhmax GFDL-ESM2M rcp85
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___GFDL-ESM2M___rcp85.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___GFDL-ESM2M___rcp85.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___HadGEM2-AO___rcp85.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85/rhmax
# # Process  rhmax HadGEM2-AO rcp85
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___HadGEM2-AO___rcp85.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___HadGEM2-AO___rcp85.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___HadGEM2-CC___rcp85.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85/rhmax
# # Process  rhmax HadGEM2-CC rcp85
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___HadGEM2-CC___rcp85.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___HadGEM2-CC___rcp85.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___HadGEM2-ES___rcp85.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85/rhmax
# # Process  rhmax HadGEM2-ES rcp85
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___HadGEM2-ES___rcp85.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___HadGEM2-ES___rcp85.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___IPSL-CM5A-LR___rcp85.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85/rhmax
# # Process  rhmax IPSL-CM5A-LR rcp85
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___IPSL-CM5A-LR___rcp85.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___IPSL-CM5A-LR___rcp85.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___IPSL-CM5A-MR___rcp85.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85/rhmax
# # Process  rhmax IPSL-CM5A-MR rcp85
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___IPSL-CM5A-MR___rcp85.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___IPSL-CM5A-MR___rcp85.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___MIROC-ESM-CHEM___rcp85.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85/rhmax
# # Process  rhmax MIROC-ESM-CHEM rcp85
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___MIROC-ESM-CHEM___rcp85.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___MIROC-ESM-CHEM___rcp85.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___MIROC-ESM___rcp85.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85/rhmax
# # Process  rhmax MIROC-ESM rcp85
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___MIROC-ESM___rcp85.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___MIROC-ESM___rcp85.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___MIROC5___rcp85.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85/rhmax
# # Process  rhmax MIROC5 rcp85
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___MIROC5___rcp85.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___MIROC5___rcp85.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___MRI-CGCM3___rcp85.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85/rhmax
# # Process  rhmax MRI-CGCM3 rcp85
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___MRI-CGCM3___rcp85.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___MRI-CGCM3___rcp85.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___NorESM1-M___rcp85.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85/rhmax
# # Process  rhmax NorESM1-M rcp85
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___NorESM1-M___rcp85.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___NorESM1-M___rcp85.nc
# rm -frv temp.nc temp2.nc
#
# # ==============================
# #  NGP_LOCA___rhmax___bcc-csm1-1-m___rcp85.nc
# #  /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85/rhmax
# cd /projects/ECEP/LOCA_MACA_Ensembles/LOCA/LOCA_NGP/Northern_Great_Plains_Original_Subset/rcp85/rhmax
# # Process  rhmax bcc-csm1-1-m rcp85
# ncap2 -h --deflate 8 -s 'lon=(lon-360)'           NGP_LOCA___rhmax___bcc-csm1-1-m___rcp85.nc temp.nc
# ncap2 -h --deflate 8 -s 'lon_bnds=(lon_bnds-360)' temp.nc temp2.nc
# mv -vf  temp2.nc NGP_LOCA___rhmax___bcc-csm1-1-m___rcp85.nc
# rm -frv temp.nc temp2.nc
